# %% [markdown]
# 1.	Load the patient master CSV file into a Pandas DataFrame
#
# 📝 Note: Use pd.read_csv() and store it in a DataFrame variable.
#
# Make sure the file path is correct.

# %%
import pandas as pd
import numpy as np
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/pandas/patient_master_1.csv")

# %% [markdown]
# 2.	Display the first 5 rows of the dataset
#
# 📝 Note: This helps you quickly understand column names, data format, and sample values.

# %%
df.head()
# Out:
#   Patient_ID First_Name Last_Name  Gender  Age Date_of_Birth Blood_Group  \
# 0     P00001     Suresh      Iyer    Male   38    1987-11-23          B+
# 1     P00002       Amit    Sharma  Female   38    1987-04-28          B+
# 2     P00003       Neha     Joshi    Male   56    1969-12-29         AB-
# 3     P00004     Anjali     Patil    Male   47    1978-12-04          A-
# 4     P00005      Rohan     Verma    Male   41    1984-02-11          A-
#
#   Marital_Status  Contact_Number        Address  ... BMI_Category  \
# 0         Single      9698790602  Local Address  ...       Normal
# 1        Married      9762620912  Local Address  ...   Overweight
# 2         Single      9522528550  Local Address  ...       Normal
# 3        Married      9196136323  Local Address  ...       Normal
# 4         Single      9644918514  Local Address  ...        Obese
#
#   Height_Normalized Weight_Standardized  Insurance_Status  \
# 0          0.166667           -1.688900               Yes
# 1          0.600000            0.340240               Yes
# 2          0.633333            0.086598               Yes
# 3          0.400000           -0.843425               Yes
# 4          0.033333            1.439358               Yes
#
#            Patient_Location  high_cardiovascular_risk  lifestyle_counseling  \
# 0  Navi Mumbai, Maharashtra                     False                  True
# 1       Mumbai, Maharashtra                     False                  True
# 2       Nashik, Maharashtra                     False                 False
# 3       Mumbai, Maharashtra                     False                 False
# 4  Navi Mumbai, Maharashtra                     False                  True
#
#   ICU-risk BMI_Rank_In_City BMI_Percentile
# 0    False           3186.0        18.4125
# 1    False           1793.0        53.8275
# 2    False           2193.0        45.2000
# 3    False           2659.0        32.1975
# 4    False             32.0        99.0525
#
# [5 rows x 42 columns]

# %% [markdown]
# 3.	Display the last 5 rows of the dataset
#
# 📝 Note: Useful to verify the ending records and check data completeness.

# %%
df.tail()
# Out:
#       Patient_ID First_Name Last_Name  Gender  Age Date_of_Birth Blood_Group  \
# 19995     P19996     Anjali     Mehta    Male   36    1989-10-07          A-
# 19996     P19997      Vikas     Verma  Female   57    1968-10-05         AB-
# 19997     P19998     Anjali     Singh  Female   46    1979-01-16          A-
# 19998     P19999       Amit    Sharma  Female   43    1982-07-30          A-
# 19999     P20000      Pooja     Gupta  Female   58    1967-02-17          O-
#
#       Marital_Status  Phone_Number               Email  ... Height_cm  \
# 19995         Single    9990287038  user19996@mail.com  ...       173
# 19996         Single    9498150434  user19997@mail.com  ...       174
# 19997        Married    9852974113  user19998@mail.com  ...       167
# 19998         Single    9925330649  user19999@mail.com  ...       157
# 19999         Single    9951983597  user20000@mail.com  ...       155
#
#       Weight_kg   BMI Smoking_Status  Alcohol_Consumption  Chronic_Condition  \
# 19995        63  21.0             No         Occasionally       Hypertension
# 19996        61  20.1            Yes         Occasionally       Hypertension
# 19997        55  19.7             No         Occasionally                NaN
# 19998        71  28.8            Yes         Occasionally                NaN
# 19999        89  37.0            Yes         Occasionally             Asthma
#
#        Primary_Doctor_ID   Insurance_Provider Insurance_Policy_No  \
# 19995               D108        ICICI Lombard           POL308290
# 19996               D102  New India Assurance           POL513474
# 19997               D105          Star Health           POL129135
# 19998               D108        ICICI Lombard           POL531241
# 19999               D101  New India Assurance           POL666690
#
#       Registration_Date
# 19995        2021-07-03
# 19996        2024-01-18
# 19997        2020-03-02
# 19998        2023-04-02
# 19999        2020-02-18
#
# [5 rows x 25 columns]

# %% [markdown]
# 4.	Find the total number of rows and columns
#
# 📝 Note: Output should be in the form (rows, columns).

# %%
df.shape
# Out:
# (20000, 25)

# %% [markdown]
# 5.	Display column names
#
# 📝 Note: Helps identify exact column names to avoid spelling mistakes later.

# %%
df.columns
# Out:
# Index(['Patient_ID', 'First_Name', 'Last_Name', 'Gender', 'Age',
#        'Date_of_Birth', 'Blood_Group', 'Marital_Status', 'Contact_Number',
#        'Address', 'City', 'State', 'Country', 'Pincode', 'Height_cm',
#        'Weight_kg', 'BMI', 'Smoking_Status', 'Alcohol_Consumption',
#        'Chronic_Condition', 'Primary_Doctor_ID', 'Insurance_Provider',
#        'Insurance_Policy_No', 'Registration_Date', 'Registration_Date_new',
#        'Under_weighted', 'Age_Group', 'Risk_level', 'Registration_Month',
#        'Registartion_Year', 'Is_Senior', 'High_Risk_Patient', 'BMI_Category',
#        'Height_Normalized', 'Weight_Standardized', 'Insurance_Status',
#        'Patient_Location', 'high_cardiovascular_risk', 'lifestyle_counseling',
#        'ICU-risk', 'BMI_Rank_In_City', 'BMI_Percentile'],
#       dtype='object')

# %% [markdown]
# 6.	Display data types of all columns
#
# 📝 Note: Verify whether numeric columns are stored as int/float and dates as object/datetime.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Patient_ID           20000 non-null  object
#  1   First_Name           20000 non-null  object
#  2   Last_Name            20000 non-null  object
#  3   Gender               20000 non-null  object
#  4   Age                  20000 non-null  int64
#  5   Date_of_Birth        20000 non-null  object
#  6   Blood_Group          20000 non-null  object
#  7   Marital_Status       20000 non-null  object
#  8   Phone_Number         20000 non-null  int64
#  9   Email                20000 non-null  object
#  10  Address              20000 non-null  object
#  11  City                 20000 non-null  object
#  12  State                20000 non-null  object
#  13  Country              20000 non-null  object
#  14  Pincode              20000 non-null  int64
#  15  Height_cm            20000 non-null  int64
#  16  Weight_kg            20000 non-null  int64
#  17  BMI                  20000 non-null  float64
#  18  Smoking_Status       20000 non-null  object
#  19  Alcohol_Consumption  20000 non-null  object
#  20  Chronic_Condition    15991 non-null  object
#  21  Primary_Doctor_ID    20000 non-null  object
#  22  Insurance_Provider   20000 non-null  object
#  23  Insurance_Policy_No  20000 non-null  object
#  24  Registration_Date    20000 non-null  object
# dtypes: float64(1), int64(5), object(19)
# memory usage: 3.8+ MB

# %%
df['Date_of_Birth'] = pd.to_datetime(df['Date_of_Birth']).dt.date

# %% [markdown]
# 7.	Show summary statistics for numerical columns
#
# 📝 Note: Includes count, mean, min, max, and standard deviation.

# %%
df.describe()
# Out:
#                 Age  Phone_Number        Pincode     Height_cm     Weight_kg  \
# count  20000.000000  2.000000e+04   20000.000000  20000.000000  20000.000000
# mean      43.882750  9.499262e+09  405528.641150    165.002850     69.975750
# std        9.481455  2.885452e+08    3206.324183      8.910382     11.827669
# min       27.000000  9.000107e+09  400001.000000    150.000000     50.000000
# 25%       36.000000  9.251704e+09  402766.500000    157.000000     60.000000
# 50%       44.000000  9.497135e+09  405511.000000    165.000000     70.000000
# 75%       52.000000  9.750070e+09  408298.250000    173.000000     80.000000
# max       60.000000  9.999997e+09  411099.000000    180.000000     90.000000
#
#                 BMI
# count  20000.000000
# mean      25.927300
# std        5.233785
# min       15.400000
# 25%       21.800000
# 50%       25.600000
# 75%       29.500000
# max       40.000000

# %% [markdown]
# 8.	Show summary statistics for all columns
#
# 📝 Note: Includes categorical stats like unique values and most frequent value.

# %%
df.describe(include='all')
# Out:
#        Patient_ID First_Name Last_Name Gender           Age Date_of_Birth  \
# count       20000      20000     20000  20000  20000.000000         20000
# unique      20000         10        10      2           NaN          9778
# top        P19984      Pooja     Patil   Male           NaN    1975-06-07
# freq            1       2085      2067  10142           NaN             8
# mean          NaN        NaN       NaN    NaN     43.882750           NaN
# std           NaN        NaN       NaN    NaN      9.481455           NaN
# min           NaN        NaN       NaN    NaN     27.000000           NaN
# 25%           NaN        NaN       NaN    NaN     36.000000           NaN
# 50%           NaN        NaN       NaN    NaN     44.000000           NaN
# 75%           NaN        NaN       NaN    NaN     52.000000           NaN
# max           NaN        NaN       NaN    NaN     60.000000           NaN
#
#        Blood_Group Marital_Status  Contact_Number        Address  ...  \
# count        20000          20000    2.000000e+04          20000  ...
# unique           8              2             NaN              1  ...
# top             A+         Single             NaN  Local Address  ...
# freq          2590          10027             NaN          20000  ...
# mean           NaN            NaN    9.499262e+09            NaN  ...
# std            NaN            NaN    2.885452e+08            NaN  ...
# min            NaN            NaN    9.000107e+09            NaN  ...
# 25%            NaN            NaN    9.251704e+09            NaN  ...
# 50%            NaN            NaN    9.497135e+09            NaN  ...
# 75%            NaN            NaN    9.750070e+09            NaN  ...
# max            NaN            NaN    9.999997e+09            NaN  ...
#
#        BMI_Category Height_Normalized Weight_Standardized  Insurance_Status  \
# count         20000      20000.000000        2.000000e+04             20000
# unique            4               NaN                 NaN                 1
# top          Normal               NaN                 NaN               Yes
# freq           7809               NaN                 NaN             20000
# mean            NaN          0.500095       -4.199308e-16               NaN
# std             NaN          0.297013        1.000000e+00               NaN
# min             NaN          0.000000       -1.688900e+00               NaN
# 25%             NaN          0.233333       -8.434248e-01               NaN
# 50%             NaN          0.500000        2.050277e-03               NaN
# 75%             NaN          0.766667        8.475254e-01               NaN
# max             NaN          1.000000        1.693001e+00               NaN
#
#          Patient_Location  high_cardiovascular_risk  lifestyle_counseling  \
# count               20000                     20000                 20000
# unique                  5                         1                     2
# top     Pune, Maharashtra                     False                  True
# freq                 4099                     20000                 17667
# mean                  NaN                       NaN                   NaN
# std                   NaN                       NaN                   NaN
# min                   NaN                       NaN                   NaN
# 25%                   NaN                       NaN                   NaN
# 50%                   NaN                       NaN                   NaN
# 75%                   NaN                       NaN                   NaN
# max                   NaN                       NaN                   NaN
#
#        ICU-risk BMI_Rank_In_City BMI_Percentile
# count     20000     20000.000000   20000.000000
# unique        1              NaN            NaN
# top       False              NaN            NaN
# freq      20000              NaN            NaN
# mean        NaN      1988.926250      50.002500
# std         NaN      1156.379089      28.867568
# min         NaN         1.000000       0.030000
# 25%         NaN       990.000000      24.740000
# 50%         NaN      1987.000000      49.815000
# 75%         NaN      2992.000000      75.067500
# max         NaN      4096.000000      99.955000
#
# [11 rows x 42 columns]

# %% [markdown]
# 9.	Check how many missing values exist per column
#
# 📝 Note: Identify columns that need data cleaning or filling.

# %%
df.isnull().sum()
# Out:
# Patient_ID                  0
# First_Name                  0
# Last_Name                   0
# Gender                      0
# Age                         0
# Date_of_Birth               0
# Blood_Group                 0
# Marital_Status              0
# Contact_Number              0
# Address                     0
# City                        0
# State                       0
# Country                     0
# Pincode                     0
# Height_cm                   0
# Weight_kg                   0
# BMI                         0
# Smoking_Status              0
# Alcohol_Consumption         0
# Chronic_Condition           0
# Primary_Doctor_ID           0
# Insurance_Provider          0
# Insurance_Policy_No         0
# Registration_Date           0
# Registration_Date_new       0
# Under_weighted              0
# Age_Group                   0
# Risk_level                  0
# Registration_Month          0
# Registartion_Year           0
# Is_Senior                   0
# High_Risk_Patient           0
# BMI_Category                0
# Height_Normalized           0
# Weight_Standardized         0
# Insurance_Status            0
# Patient_Location            0
# high_cardiovascular_risk    0
# lifestyle_counseling        0
# ICU-risk                    0
# BMI_Rank_In_City            0
# BMI_Percentile              0
# dtype: int64

# %% [markdown]
# 10.	Check if the dataset contains duplicate Patient_IDs
#
# 📝 Note: Patient_ID should be unique; duplicates indicate data quality issues.

# %%
df['Patient_ID'].duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# 11.	Find the total number of unique patients
#
# 📝 Note: Use Patient_ID to verify uniqueness.

# %%
df['Patient_ID'].nunique()
# Out:
# 20000

# %% [markdown]
# 12.	Display memory usage of the DataFrame
#
# 📝 Note: Important when working with large healthcare datasets.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 42 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Patient_ID                20000 non-null  object
#  1   First_Name                20000 non-null  object
#  2   Last_Name                 20000 non-null  object
#  3   Gender                    20000 non-null  category
#  4   Age                       20000 non-null  int64
#  5   Date_of_Birth             20000 non-null  object
#  6   Blood_Group               20000 non-null  category
#  7   Marital_Status            20000 non-null  object
#  8   Contact_Number            20000 non-null  int64
#  9   Address                   20000 non-null  object
#  10  City                      20000 non-null  object
#  11  State                     20000 non-null  object
#  12  Country                   20000 non-null  object
#  13  Pincode                   20000 non-null  int64
#  14  Height_cm                 20000 non-null  int64
#  15  Weight_kg                 20000 non-null  int64
#  16  BMI                       20000 non-null  float64
#  17  Smoking_Status            20000 non-null  object
#  18  Alcohol_Consumption       20000 non-null  object
#  19  Chronic_Condition         20000 non-null  object
#  20  Primary_Doctor_ID         20000 non-null  object
#  21  Insurance_Provider        20000 non-null  object
#  22  Insurance_Policy_No       20000 non-null  object
#  23  Registration_Date         20000 non-null  object
#  24  Registration_Date_new     20000 non-null  int32
#  25  Under_weighted            20000 non-null  bool
#  26  Age_Group                 20000 non-null  object
#  27  Risk_level                20000 non-null  object
#  28  Registration_Month        20000 non-null  int32
#  29  Registartion_Year         20000 non-null  int32
#  30  Is_Senior                 20000 non-null  object
#  31  High_Risk_Patient         20000 non-null  bool
#  32  BMI_Category              20000 non-null  object
#  33  Height_Normalized         20000 non-null  float64
#  34  Weight_Standardized       20000 non-null  float64
#  35  Insurance_Status          20000 non-null  object
#  36  Patient_Location          20000 non-null  object
#  37  high_cardiovascular_risk  20000 non-null  bool
#  38  lifestyle_counseling      20000 non-null  bool
#  39  ICU-risk                  20000 non-null  bool
#  40  BMI_Rank_In_City          20000 non-null  float64
#  41  BMI_Percentile            20000 non-null  float64
# dtypes: bool(5), category(2), float64(5), int32(3), int64(5), object(22)
# memory usage: 5.2+ MB

# %% [markdown]
# 13.	Sort patients by Age in descending order
#
# 📝 Note: Oldest patients should appear first.

# %%
df.sort_values(by='Age', ascending=False)
# Out:
#       Patient_ID First_Name Last_Name  Gender  Age Date_of_Birth Blood_Group  \
# 8399      P08400      Sneha     Singh  Female   60    1965-08-07         AB-
# 19        P00020      Pooja     Joshi  Female   60    1965-07-26          B+
# 14971     P14972      Sneha    Sharma  Female   60    1965-04-13          A-
# 1148      P01149     Anjali     Verma    Male   60    1965-04-25          O+
# 1149      P01150       Neha     Gupta    Male   60    1965-04-25          A+
# ...          ...        ...       ...     ...  ...           ...         ...
# 13482     P13483     Anjali     Singh  Female   27    1998-01-11          A+
# 8050      P08051      Rahul     Patil  Female   27    1998-01-10          B-
# 16179     P16180     Anjali     Patil    Male   27    1998-01-18          A+
# 16191     P16192     Anjali     Gupta    Male   27    1998-01-18         AB-
# 3456      P03457      Vikas     Verma  Female   27    1998-01-16          A+
#
#       Marital_Status  Contact_Number        Address  ... BMI_Category  \
# 8399          Single      9095205309  Local Address  ...       Normal
# 19            Single      9602891328  Local Address  ...        Obese
# 14971         Single      9763313339  Local Address  ...       Normal
# 1148          Single      9311576340  Local Address  ...   Overweight
# 1149         Married      9481744526  Local Address  ...        Obese
# ...              ...             ...            ...  ...          ...
# 13482         Single      9282284476  Local Address  ...   Overweight
# 8050          Single      9492374105  Local Address  ...  Underweight
# 16179        Married      9690272656  Local Address  ...   Overweight
# 16191         Single      9619731561  Local Address  ...        Obese
# 3456         Married      9443674753  Local Address  ...       Normal
#
#       Height_Normalized Weight_Standardized  Insurance_Status  \
# 8399           0.333333           -0.589782               Yes
# 19             0.733333            1.608453               Yes
# 14971          0.833333           -0.505235               Yes
# 1148           0.166667           -0.420687               Yes
# 1149           0.533333            1.270263               Yes
# ...                 ...                 ...               ...
# 13482          0.366667            0.424788               Yes
# 8050           0.900000           -1.350710               Yes
# 16179          0.400000            0.171145               Yes
# 16191          0.300000            0.932073               Yes
# 3456           0.800000            0.424788               Yes
#
#                Patient_Location  high_cardiovascular_risk  \
# 8399        Mumbai, Maharashtra                     False
# 19            Pune, Maharashtra                     False
# 14971       Nagpur, Maharashtra                     False
# 1148        Mumbai, Maharashtra                     False
# 1149   Navi Mumbai, Maharashtra                     False
# ...                         ...                       ...
# 13482       Mumbai, Maharashtra                     False
# 8050          Pune, Maharashtra                     False
# 16179  Navi Mumbai, Maharashtra                     False
# 16191  Navi Mumbai, Maharashtra                     False
# 3456          Pune, Maharashtra                     False
#
#        lifestyle_counseling ICU-risk BMI_Rank_In_City BMI_Percentile
# 8399                  False    False           2217.0        43.1875
# 19                     True    False            864.0        78.2425
# 14971                  True    False           3218.0        18.9575
# 1148                   True    False           1562.0        59.8925
# 1149                   True    False            706.0        81.1975
# ...                     ...      ...              ...            ...
# 13482                  True    False           1131.0        71.2025
# 8050                  False    False           3968.0         2.5175
# 16179                  True    False           1486.0        61.9425
# 16191                  True    False            500.0        86.0650
# 3456                   True    False           2294.0        44.5775
#
# [20000 rows x 42 columns]

# %% [markdown]
# 14.	Sort patients by Registration_Date in ascending order
#
# 📝 Note: Earliest registered patients should appear first.

# %%
df.sort_values(by='Registration_Date', ascending=True)
# Out:
#       Patient_ID First_Name Last_Name  Gender  Age Date_of_Birth Blood_Group  \
# 17264     P17265       Amit      Iyer    Male   46    1979-12-10          O+
# 16781     P16782       Amit     Gupta    Male   35    1990-07-15          A-
# 3817      P03818      Vikas  Kulkarni    Male   37    1988-10-20          O+
# 3955      P03956      Rohan     Mehta  Female   44    1981-03-03         AB-
# 18676     P18677      Rohan     Mehta  Female   34    1991-11-30          B+
# ...          ...        ...       ...     ...  ...           ...         ...
# 9220      P09221     Anjali    Sharma    Male   40    1985-07-24          B+
# 934       P00935     Suresh     Gupta  Female   52    1973-01-17          O-
# 4328      P04329     Kavita     Mehta  Female   47    1978-07-01          A+
# 1431      P01432       Amit  Kulkarni  Female   35    1990-11-21          A-
# 11977     P11978      Rahul      Iyer    Male   55    1970-06-03         AB-
#
#       Marital_Status  Contact_Number        Address  ... BMI_Category  \
# 17264         Single      9104218759  Local Address  ...   Overweight
# 16781        Married      9030455935  Local Address  ...       Normal
# 3817          Single      9196624830  Local Address  ...        Obese
# 3955         Married      9639101257  Local Address  ...   Overweight
# 18676        Married      9720232207  Local Address  ...        Obese
# ...              ...             ...            ...  ...          ...
# 9220         Married      9565398228  Local Address  ...        Obese
# 934          Married      9536300592  Local Address  ...        Obese
# 4328         Married      9318381480  Local Address  ...       Normal
# 1431         Married      9783573955  Local Address  ...   Overweight
# 11977         Single      9384205947  Local Address  ...        Obese
#
#       Height_Normalized Weight_Standardized  Insurance_Status  \
# 17264          0.300000           -0.082497               Yes
# 16781          0.833333           -0.082497               Yes
# 3817           0.033333            0.171145               Yes
# 3955           0.333333            0.340240               Yes
# 18676          0.000000            0.255693               Yes
# ...                 ...                 ...               ...
# 9220           0.266667            0.509335               Yes
# 934            0.666667            1.439358               Yes
# 4328           0.766667           -1.097067               Yes
# 1431           0.600000            1.016620               Yes
# 11977          0.400000            1.101168               Yes
#
#                Patient_Location  high_cardiovascular_risk  \
# 17264  Navi Mumbai, Maharashtra                     False
# 16781       Nagpur, Maharashtra                     False
# 3817        Nagpur, Maharashtra                     False
# 3955        Nashik, Maharashtra                     False
# 18676         Pune, Maharashtra                     False
# ...                         ...                       ...
# 9220   Navi Mumbai, Maharashtra                     False
# 934         Mumbai, Maharashtra                     False
# 4328          Pune, Maharashtra                     False
# 1431   Navi Mumbai, Maharashtra                     False
# 11977       Nashik, Maharashtra                     False
#
#        lifestyle_counseling ICU-risk BMI_Rank_In_City BMI_Percentile
# 17264                  True    False           1514.0        61.2675
# 16781                  True    False           2816.0        29.4375
# 3817                   True    False            615.0        84.5575
# 3955                   True    False           1139.0        71.2025
# 18676                  True    False            521.0        87.2875
# ...                     ...      ...              ...            ...
# 9220                   True    False            787.0        79.4525
# 934                    True    False            840.0        78.2425
# 4328                   True    False           3718.0         9.0525
# 1431                   True    False           1077.0        72.5650
# 11977                  True    False            588.0        84.5575
#
# [20000 rows x 42 columns]

# %% [markdown]
# 15.	Display random 10 patient records
#
# 📝 Note: Random sampling helps quick data inspection

# %%
df.sample(10)
# Out:
#       Patient_ID First_Name Last_Name  Gender  Age Date_of_Birth Blood_Group  \
# 6800      P06801      Rohan     Singh    Male   41    1984-05-30          A+
# 6452      P06453       Amit     Mehta  Female   57    1968-11-03         AB+
# 18912     P18913      Vikas     Joshi  Female   60    1965-09-06          A+
# 18309     P18310      Rohan     Joshi    Male   43    1982-07-12          O-
# 5525      P05526       Amit    Sharma    Male   44    1981-07-11          O-
# 4917      P04918       Amit     Joshi    Male   35    1990-05-10          B-
# 13496     P13497     Suresh      Nair    Male   35    1990-05-31         AB-
# 12363     P12364       Amit      Nair  Female   29    1996-06-01         AB+
# 19175     P19176     Suresh     Joshi  Female   39    1986-06-12          O-
# 18752     P18753      Rahul     Patil  Female   37    1988-10-18         AB+
#
#       Marital_Status  Phone_Number               Email  ... Height_cm  \
# 6800          Single    9915181511   user6801@mail.com  ...       150
# 6452          Single    9743915141   user6453@mail.com  ...       173
# 18912        Married    9075855347  user18913@mail.com  ...       164
# 18309        Married    9275297219  user18310@mail.com  ...       162
# 5525         Married    9562176283   user5526@mail.com  ...       180
# 4917         Married    9355121143   user4918@mail.com  ...       155
# 13496         Single    9180534560  user13497@mail.com  ...       157
# 12363         Single    9917187755  user12364@mail.com  ...       177
# 19175        Married    9146439135  user19176@mail.com  ...       179
# 18752        Married    9840069890  user18753@mail.com  ...       168
#
#       Weight_kg   BMI Smoking_Status  Alcohol_Consumption  Chronic_Condition  \
# 6800         51  22.7             No         Occasionally       Hypertension
# 6452         50  16.7             No         Occasionally                NaN
# 18912        83  30.9             No         Occasionally            Thyroid
# 18309        58  22.1             No         Occasionally            Thyroid
# 5525         84  25.9            Yes         Occasionally       Hypertension
# 4917         58  24.1             No                   No                NaN
# 13496        86  34.9            Yes         Occasionally            Thyroid
# 12363        79  25.2            Yes         Occasionally             Asthma
# 19175        77  24.0            Yes         Occasionally            Thyroid
# 18752        76  26.9            Yes         Occasionally                NaN
#
#        Primary_Doctor_ID   Insurance_Provider Insurance_Policy_No  \
# 6800                D102            HDFC Ergo           POL843196
# 6452                D103  New India Assurance           POL811446
# 18912               D103        ICICI Lombard           POL325408
# 18309               D108  New India Assurance           POL966853
# 5525                D108          Star Health           POL753291
# 4917                D103            HDFC Ergo           POL529513
# 13496               D100  New India Assurance           POL818155
# 12363               D102     Reliance General           POL884423
# 19175               D101     Reliance General           POL507000
# 18752               D109  New India Assurance           POL675204
#
#       Registration_Date
# 6800         2020-06-23
# 6452         2020-03-26
# 18912        2023-03-13
# 18309        2021-07-13
# 5525         2020-09-26
# 4917         2022-02-09
# 13496        2021-06-03
# 12363        2023-06-07
# 19175        2020-05-06
# 18752        2023-11-19
#
# [10 rows x 25 columns]

# %% [markdown]
# **🔹 SECTION 2: FILTERING & CONDITIONAL SELECTION (16–35)**
#
# 16.	Find all male patients
#
# 📝 Note: Filter rows where Gender equals "Male".

# %%
df[df['Gender']=='Male']
# Out:
#       Patient_ID First_Name Last_Name Gender  Age Date_of_Birth Blood_Group  \
# 0         P00001     Suresh      Iyer   Male   38    1987-11-23          B+
# 2         P00003       Neha     Joshi   Male   56    1969-12-29         AB-
# 3         P00004     Anjali     Patil   Male   47    1978-12-04          A-
# 4         P00005      Rohan     Verma   Male   41    1984-02-11          A-
# 5         P00006     Suresh  Kulkarni   Male   46    1979-09-03          A+
# ...          ...        ...       ...    ...  ...           ...         ...
# 19988     P19989      Vikas     Patil   Male   54    1971-07-25         AB-
# 19989     P19990      Pooja     Joshi   Male   35    1990-07-24         AB-
# 19990     P19991      Vikas     Joshi   Male   55    1970-05-20          O+
# 19994     P19995     Suresh     Singh   Male   58    1967-01-14         AB+
# 19995     P19996     Anjali     Mehta   Male   36    1989-10-07          A-
#
#       Marital_Status  Contact_Number        Address  ... BMI_Category  \
# 0             Single      9698790602  Local Address  ...       Normal
# 2             Single      9522528550  Local Address  ...       Normal
# 3            Married      9196136323  Local Address  ...       Normal
# 4             Single      9644918514  Local Address  ...        Obese
# 5            Married      9469747118  Local Address  ...        Obese
# ...              ...             ...            ...  ...          ...
# 19988        Married      9087089590  Local Address  ...       Normal
# 19989        Married      9823010533  Local Address  ...  Underweight
# 19990         Single      9551275487  Local Address  ...   Overweight
# 19994        Married      9142595611  Local Address  ...        Obese
# 19995         Single      9990287038  Local Address  ...       Normal
#
#       Height_Normalized Weight_Standardized  Insurance_Status  \
# 0              0.166667           -1.688900               Yes
# 2              0.633333            0.086598               Yes
# 3              0.400000           -0.843425               Yes
# 4              0.033333            1.439358               Yes
# 5              0.400000            1.270263               Yes
# ...                 ...                 ...               ...
# 19988          0.233333           -0.927972               Yes
# 19989          0.933333           -1.266162               Yes
# 19990          0.333333            0.002050               Yes
# 19994          0.200000            0.593883               Yes
# 19995          0.766667           -0.589782               Yes
#
#                Patient_Location  high_cardiovascular_risk  \
# 0      Navi Mumbai, Maharashtra                     False
# 2           Nashik, Maharashtra                     False
# 3           Mumbai, Maharashtra                     False
# 4      Navi Mumbai, Maharashtra                     False
# 5      Navi Mumbai, Maharashtra                     False
# ...                         ...                       ...
# 19988         Pune, Maharashtra                     False
# 19989       Mumbai, Maharashtra                     False
# 19990       Nagpur, Maharashtra                     False
# 19994  Navi Mumbai, Maharashtra                     False
# 19995  Navi Mumbai, Maharashtra                     False
#
#        lifestyle_counseling ICU-risk BMI_Rank_In_City BMI_Percentile
# 0                      True    False           3186.0        18.4125
# 2                     False    False           2193.0        45.2000
# 3                     False    False           2659.0        32.1975
# 4                      True    False             32.0        99.0525
# 5                      True    False            468.0        87.2875
# ...                     ...      ...              ...            ...
# 19988                  True    False           2520.0        38.6975
# 19989                  True    False           3822.0         2.9900
# 19990                  True    False           1532.0        61.2675
# 19994                  True    False            557.0        84.5575
# 19995                  True    False           3128.0        19.5950
#
# [10142 rows x 42 columns]

# %% [markdown]
# 17.	Find all female patients above 50 years
#
# 📝 Note: Apply two conditions: Gender = Female AND Age > 50.

# %%
df[(df['Gender']=='Female') & (df['Age']>=50)]
# Out:
#       Patient_ID First_Name Last_Name  Gender  Age Date_of_Birth Blood_Group  \
# 7         P00008      Vikas     Gupta  Female   59    1966-03-23         AB+
# 10        P00011      Sneha     Verma  Female   51    1974-03-31          O-
# 11        P00012      Rahul     Mehta  Female   50    1975-11-26         AB-
# 12        P00013      Vikas     Verma  Female   56    1969-08-17          A-
# 18        P00019      Rahul      Iyer  Female   50    1975-05-13          O-
# ...          ...        ...       ...     ...  ...           ...         ...
# 19968     P19969     Suresh     Singh  Female   56    1969-09-07         AB-
# 19983     P19984      Rahul      Iyer  Female   54    1971-07-06          A+
# 19992     P19993      Rahul      Iyer  Female   58    1967-01-17         AB-
# 19996     P19997      Vikas     Verma  Female   57    1968-10-05         AB-
# 19999     P20000      Pooja     Gupta  Female   58    1967-02-17          O-
#
#       Marital_Status  Phone_Number               Email  ... Height_cm  \
# 7            Married    9000565982      user8@mail.com  ...       173
# 10            Single    9227251578     user11@mail.com  ...       180
# 11           Married    9380410557     user12@mail.com  ...       170
# 12            Single    9895288162     user13@mail.com  ...       165
# 18            Single    9270700539     user19@mail.com  ...       167
# ...              ...           ...                 ...  ...       ...
# 19968        Married    9880393201  user19969@mail.com  ...       170
# 19983        Married    9242052517  user19984@mail.com  ...       174
# 19992         Single    9138504573  user19993@mail.com  ...       174
# 19996         Single    9498150434  user19997@mail.com  ...       174
# 19999         Single    9951983597  user20000@mail.com  ...       155
#
#       Weight_kg   BMI Smoking_Status  Alcohol_Consumption  Chronic_Condition  \
# 7            60  20.0            Yes         Occasionally       Hypertension
# 10           89  27.5            Yes                   No       Hypertension
# 11           82  28.4             No         Occasionally             Asthma
# 12           86  31.6             No                   No                NaN
# 18           85  30.5             No         Occasionally            Thyroid
# ...         ...   ...            ...                  ...                ...
# 19968        65  22.5             No         Occasionally                NaN
# 19983        55  18.2            Yes                   No           Diabetes
# 19992        63  20.8             No                   No           Diabetes
# 19996        61  20.1            Yes         Occasionally       Hypertension
# 19999        89  37.0            Yes         Occasionally             Asthma
#
#        Primary_Doctor_ID   Insurance_Provider Insurance_Policy_No  \
# 7                   D100            HDFC Ergo           POL523880
# 10                  D104     Reliance General           POL777223
# 11                  D110     Reliance General           POL684731
# 12                  D102     Reliance General           POL970598
# 18                  D109  New India Assurance           POL826506
# ...                  ...                  ...                 ...
# 19968               D102          Star Health           POL690634
# 19983               D102  New India Assurance           POL778154
# 19992               D104          Star Health           POL871461
# 19996               D102  New India Assurance           POL513474
# 19999               D101  New India Assurance           POL666690
#
#       Registration_Date
# 7            2022-03-23
# 10           2021-04-24
# 11           2022-12-15
# 12           2022-10-01
# 18           2024-01-30
# ...                 ...
# 19968        2020-03-29
# 19983        2021-12-26
# 19992        2020-12-23
# 19996        2024-01-18
# 19999        2020-02-18
#
# [3276 rows x 25 columns]

# %% [markdown]
# 18.	Find patients from Pune city
#
# 📝 Note: Match exact city name in City column.

# %%
df[df['City'] == 'Pune']
# Out:
#       Patient_ID First_Name Last_Name  Gender  Age Date_of_Birth Blood_Group  \
# 6         P00007     Suresh      Nair    Male   42    1983-02-17          B-
# 7         P00008      Vikas     Gupta  Female   59    1966-03-23         AB+
# 10        P00011      Sneha     Verma  Female   51    1974-03-31          O-
# 15        P00016      Pooja      Iyer    Male   41    1984-04-04         AB-
# 16        P00017       Neha     Gupta  Female   37    1988-05-03          B-
# ...          ...        ...       ...     ...  ...           ...         ...
# 19966     P19967     Kavita     Patil  Female   57    1968-12-21          A-
# 19970     P19971      Vikas     Singh    Male   50    1975-08-05          B-
# 19972     P19973       Neha  Kulkarni    Male   54    1971-02-04          B-
# 19987     P19988      Rohan     Joshi    Male   46    1979-05-02          B-
# 19988     P19989      Vikas     Patil    Male   54    1971-07-25         AB-
#
#       Marital_Status  Phone_Number               Email  ... Height_cm  \
# 6             Single    9199546251      user7@mail.com  ...       176
# 7            Married    9000565982      user8@mail.com  ...       173
# 10            Single    9227251578     user11@mail.com  ...       180
# 15           Married    9131640457     user16@mail.com  ...       152
# 16            Single    9625970283     user17@mail.com  ...       177
# ...              ...           ...                 ...  ...       ...
# 19966         Single    9771991467  user19967@mail.com  ...       173
# 19970         Single    9694795979  user19971@mail.com  ...       154
# 19972        Married    9719340286  user19973@mail.com  ...       166
# 19987        Married    9549739409  user19988@mail.com  ...       163
# 19988        Married    9087089590  user19989@mail.com  ...       157
#
#       Weight_kg   BMI Smoking_Status  Alcohol_Consumption  Chronic_Condition  \
# 6            88  28.4            Yes                   No                NaN
# 7            60  20.0            Yes         Occasionally       Hypertension
# 10           89  27.5            Yes                   No       Hypertension
# 15           86  37.2            Yes         Occasionally           Diabetes
# 16           52  16.6            Yes         Occasionally                NaN
# ...         ...   ...            ...                  ...                ...
# 19966        89  29.7            Yes                   No       Hypertension
# 19970        80  33.7             No         Occasionally       Hypertension
# 19972        53  19.2             No                   No       Hypertension
# 19987        59  22.2             No                   No                NaN
# 19988        59  23.9             No         Occasionally       Hypertension
#
#        Primary_Doctor_ID  Insurance_Provider Insurance_Policy_No  \
# 6                   D108    Reliance General           POL682287
# 7                   D100           HDFC Ergo           POL523880
# 10                  D104    Reliance General           POL777223
# 15                  D107    Reliance General           POL773678
# 16                  D107           HDFC Ergo           POL948459
# ...                  ...                 ...                 ...
# 19966               D107    Reliance General           POL374313
# 19970               D100    Reliance General           POL958429
# 19972               D110    Reliance General           POL544991
# 19987               D105           HDFC Ergo           POL189197
# 19988               D103       ICICI Lombard           POL272280
#
#       Registration_Date
# 6            2020-03-22
# 7            2022-03-23
# 10           2021-04-24
# 15           2022-10-31
# 16           2020-07-27
# ...                 ...
# 19966        2022-07-11
# 19970        2022-09-12
# 19972        2023-02-27
# 19987        2023-08-05
# 19988        2023-10-27
#
# [4099 rows x 25 columns]

# %% [markdown]
# 19.	Find patients suffering from Diabetes
#
# 📝 Note: Use Chronic_Condition column and filter "Diabetes".

# %%
df[df['Chronic_Condition']=='Diabetes']
# Out:
#       Patient_ID First_Name Last_Name  Gender  Age Date_of_Birth Blood_Group  \
# 3         P00004     Anjali     Patil    Male   47    1978-12-04          A-
# 13        P00014     Suresh     Mehta  Female   39    1986-05-10          A-
# 15        P00016      Pooja      Iyer    Male   41    1984-04-04         AB-
# 19        P00020      Pooja     Joshi  Female   60    1965-07-26          B+
# 24        P00025      Pooja      Nair    Male   34    1991-01-25         AB+
# ...          ...        ...       ...     ...  ...           ...         ...
# 19982     P19983      Rohan     Mehta    Male   42    1983-04-13          B+
# 19983     P19984      Rahul      Iyer  Female   54    1971-07-06          A+
# 19989     P19990      Pooja     Joshi    Male   35    1990-07-24         AB-
# 19992     P19993      Rahul      Iyer  Female   58    1967-01-17         AB-
# 19993     P19994     Anjali     Joshi  Female   43    1982-04-25          O-
#
#       Marital_Status  Phone_Number               Email  ... Height_cm  \
# 3            Married    9196136323      user4@mail.com  ...       162
# 13           Married    9240144188     user14@mail.com  ...       165
# 15           Married    9131640457     user16@mail.com  ...       152
# 19            Single    9602891328     user20@mail.com  ...       172
# 24            Single    9415300588     user25@mail.com  ...       163
# ...              ...           ...                 ...  ...       ...
# 19982         Single    9143638855  user19983@mail.com  ...       175
# 19983        Married    9242052517  user19984@mail.com  ...       174
# 19989        Married    9823010533  user19990@mail.com  ...       178
# 19992         Single    9138504573  user19993@mail.com  ...       174
# 19993        Married    9864695122  user19994@mail.com  ...       173
#
#       Weight_kg   BMI Smoking_Status  Alcohol_Consumption  Chronic_Condition  \
# 3            60  22.9             No                   No           Diabetes
# 13           76  27.9            Yes                   No           Diabetes
# 15           86  37.2            Yes         Occasionally           Diabetes
# 19           89  30.1            Yes                   No           Diabetes
# 24           58  21.8            Yes         Occasionally           Diabetes
# ...         ...   ...            ...                  ...                ...
# 19982        86  28.1             No         Occasionally           Diabetes
# 19983        55  18.2            Yes                   No           Diabetes
# 19989        55  17.4            Yes         Occasionally           Diabetes
# 19992        63  20.8             No                   No           Diabetes
# 19993        62  20.7             No         Occasionally           Diabetes
#
#        Primary_Doctor_ID   Insurance_Provider Insurance_Policy_No  \
# 3                   D101     Reliance General           POL912134
# 13                  D102          Star Health           POL980183
# 15                  D107     Reliance General           POL773678
# 19                  D109  New India Assurance           POL316461
# 24                  D103  New India Assurance           POL974247
# ...                  ...                  ...                 ...
# 19982               D100  New India Assurance           POL483547
# 19983               D102  New India Assurance           POL778154
# 19989               D108          Star Health           POL229492
# 19992               D104          Star Health           POL871461
# 19993               D109     Reliance General           POL507705
#
#       Registration_Date
# 3            2020-05-17
# 13           2022-12-17
# 15           2022-10-31
# 19           2022-04-16
# 24           2021-12-02
# ...                 ...
# 19982        2023-03-18
# 19983        2021-12-26
# 19989        2022-07-08
# 19992        2020-12-23
# 19993        2020-07-05
#
# [4014 rows x 25 columns]

# %% [markdown]
# 20.	Find patients who are smokers
#
# 📝 Note: Filter Smoking_Status column for "Yes".

# %%
df[df['Smoking_Status']=='Yes']
# Out:
#       Patient_ID First_Name Last_Name  Gender  Age Date_of_Birth Blood_Group  \
# 0         P00001     Suresh      Iyer    Male   38    1987-11-23          B+
# 1         P00002       Amit    Sharma  Female   38    1987-04-28          B+
# 6         P00007     Suresh      Nair    Male   42    1983-02-17          B-
# 7         P00008      Vikas     Gupta  Female   59    1966-03-23         AB+
# 8         P00009     Kavita     Mehta  Female   30    1995-03-30          A+
# ...          ...        ...       ...     ...  ...           ...         ...
# 19991     P19992      Vikas    Sharma  Female   39    1986-11-17         AB-
# 19994     P19995     Suresh     Singh    Male   58    1967-01-14         AB+
# 19996     P19997      Vikas     Verma  Female   57    1968-10-05         AB-
# 19998     P19999       Amit    Sharma  Female   43    1982-07-30          A-
# 19999     P20000      Pooja     Gupta  Female   58    1967-02-17          O-
#
#       Marital_Status  Phone_Number               Email  ... Height_cm  \
# 0             Single    9698790602      user1@mail.com  ...       155
# 1            Married    9762620912      user2@mail.com  ...       168
# 6             Single    9199546251      user7@mail.com  ...       176
# 7            Married    9000565982      user8@mail.com  ...       173
# 8            Married    9853397700      user9@mail.com  ...       155
# ...              ...           ...                 ...  ...       ...
# 19991         Single    9978783159  user19992@mail.com  ...       159
# 19994        Married    9142595611  user19995@mail.com  ...       156
# 19996         Single    9498150434  user19997@mail.com  ...       174
# 19998         Single    9925330649  user19999@mail.com  ...       157
# 19999         Single    9951983597  user20000@mail.com  ...       155
#
#       Weight_kg   BMI Smoking_Status  Alcohol_Consumption  Chronic_Condition  \
# 0            50  20.8            Yes         Occasionally            Thyroid
# 1            74  26.2            Yes         Occasionally                NaN
# 6            88  28.4            Yes                   No                NaN
# 7            60  20.0            Yes         Occasionally       Hypertension
# 8            68  28.3            Yes                   No             Asthma
# ...         ...   ...            ...                  ...                ...
# 19991        85  33.6            Yes         Occasionally            Thyroid
# 19994        77  31.6            Yes                   No       Hypertension
# 19996        61  20.1            Yes         Occasionally       Hypertension
# 19998        71  28.8            Yes         Occasionally                NaN
# 19999        89  37.0            Yes         Occasionally             Asthma
#
#        Primary_Doctor_ID   Insurance_Provider Insurance_Policy_No  \
# 0                   D110     Reliance General           POL127128
# 1                   D102          Star Health           POL919951
# 6                   D108     Reliance General           POL682287
# 7                   D100            HDFC Ergo           POL523880
# 8                   D103          Star Health           POL233712
# ...                  ...                  ...                 ...
# 19991               D102        ICICI Lombard           POL329569
# 19994               D109            HDFC Ergo           POL281542
# 19996               D102  New India Assurance           POL513474
# 19998               D108        ICICI Lombard           POL531241
# 19999               D101  New India Assurance           POL666690
#
#       Registration_Date
# 0            2023-10-19
# 1            2023-02-12
# 6            2020-03-22
# 7            2022-03-23
# 8            2020-10-24
# ...                 ...
# 19991        2023-12-03
# 19994        2021-12-02
# 19996        2024-01-18
# 19998        2023-04-02
# 19999        2020-02-18
#
# [9964 rows x 25 columns]

# %% [markdown]
# 21.	Find patients who consume alcohol occasionally
#
# 📝 Note: Match Alcohol_Consumption = "Occasionally".

# %%
df[df['Alcohol_Consumption']=='Occasionally']
# Out:
#       Patient_ID First_Name Last_Name  Gender  Age Date_of_Birth Blood_Group  \
# 0         P00001     Suresh      Iyer    Male   38    1987-11-23          B+
# 1         P00002       Amit    Sharma  Female   38    1987-04-28          B+
# 5         P00006     Suresh  Kulkarni    Male   46    1979-09-03          A+
# 7         P00008      Vikas     Gupta  Female   59    1966-03-23         AB+
# 9         P00010      Vikas      Nair    Male   58    1967-11-03         AB+
# ...          ...        ...       ...     ...  ...           ...         ...
# 19995     P19996     Anjali     Mehta    Male   36    1989-10-07          A-
# 19996     P19997      Vikas     Verma  Female   57    1968-10-05         AB-
# 19997     P19998     Anjali     Singh  Female   46    1979-01-16          A-
# 19998     P19999       Amit    Sharma  Female   43    1982-07-30          A-
# 19999     P20000      Pooja     Gupta  Female   58    1967-02-17          O-
#
#       Marital_Status  Contact_Number        Address  ... BMI_Category  \
# 0             Single      9698790602  Local Address  ...       Normal
# 1            Married      9762620912  Local Address  ...   Overweight
# 5            Married      9469747118  Local Address  ...        Obese
# 7            Married      9000565982  Local Address  ...       Normal
# 9            Married      9471311790  Local Address  ...       Normal
# ...              ...             ...            ...  ...          ...
# 19995         Single      9990287038  Local Address  ...       Normal
# 19996         Single      9498150434  Local Address  ...       Normal
# 19997        Married      9852974113  Local Address  ...       Normal
# 19998         Single      9925330649  Local Address  ...   Overweight
# 19999         Single      9951983597  Local Address  ...        Obese
#
#       Height_Normalized Weight_Standardized  Insurance_Status  \
# 0              0.166667           -1.688900               Yes
# 1              0.600000            0.340240               Yes
# 5              0.400000            1.270263               Yes
# 7              0.766667           -0.843425               Yes
# 9              0.500000           -0.251592               Yes
# ...                 ...                 ...               ...
# 19995          0.766667           -0.589782               Yes
# 19996          0.800000           -0.758877               Yes
# 19997          0.566667           -1.266162               Yes
# 19998          0.233333            0.086598               Yes
# 19999          0.166667            1.608453               Yes
#
#                Patient_Location  high_cardiovascular_risk  \
# 0      Navi Mumbai, Maharashtra                     False
# 1           Mumbai, Maharashtra                     False
# 5      Navi Mumbai, Maharashtra                     False
# 7             Pune, Maharashtra                     False
# 9           Nagpur, Maharashtra                     False
# ...                         ...                       ...
# 19995  Navi Mumbai, Maharashtra                     False
# 19996  Navi Mumbai, Maharashtra                     False
# 19997       Nagpur, Maharashtra                     False
# 19998       Nagpur, Maharashtra                     False
# 19999       Nagpur, Maharashtra                     False
#
#        lifestyle_counseling ICU-risk BMI_Rank_In_City BMI_Percentile
# 0                      True    False           3186.0        18.4125
# 1                      True    False           1793.0        53.8275
# 5                      True    False            468.0        87.2875
# 7                      True    False           3511.0        13.9500
# 9                      True    False           2251.0        43.1875
# ...                     ...      ...              ...            ...
# 19995                  True    False           3128.0        19.5950
# 19996                  True    False           3328.0        14.4375
# 19997                  True    False           3520.0        12.3325
# 19998                  True    False           1145.0        70.8675
# 19999                  True    False             90.0        97.7850
#
# [9959 rows x 42 columns]

# %% [markdown]
# 22.	Find patients with BMI greater than 30
#
# 📝 Note: BMI > 30 is considered obese (high risk).

# %%
df[df['BMI']>30]
# Out:
#       Patient_ID First_Name Last_Name  Gender  Age Date_of_Birth Blood_Group  \
# 4         P00005      Rohan     Verma    Male   41    1984-02-11          A-
# 5         P00006     Suresh  Kulkarni    Male   46    1979-09-03          A+
# 12        P00013      Vikas     Verma  Female   56    1969-08-17          A-
# 15        P00016      Pooja      Iyer    Male   41    1984-04-04         AB-
# 18        P00019      Rahul      Iyer  Female   50    1975-05-13          O-
# ...          ...        ...       ...     ...  ...           ...         ...
# 19975     P19976       Amit     Gupta    Male   57    1968-04-20         AB-
# 19977     P19978      Rahul     Gupta    Male   43    1982-07-27         AB-
# 19991     P19992      Vikas    Sharma  Female   39    1986-11-17         AB-
# 19994     P19995     Suresh     Singh    Male   58    1967-01-14         AB+
# 19999     P20000      Pooja     Gupta  Female   58    1967-02-17          O-
#
#       Marital_Status  Phone_Number               Email  ... Height_cm  \
# 4             Single    9644918514      user5@mail.com  ...       151
# 5            Married    9469747118      user6@mail.com  ...       162
# 12            Single    9895288162     user13@mail.com  ...       165
# 15           Married    9131640457     user16@mail.com  ...       152
# 18            Single    9270700539     user19@mail.com  ...       167
# ...              ...           ...                 ...  ...       ...
# 19975        Married    9460741360  user19976@mail.com  ...       153
# 19977        Married    9402505693  user19978@mail.com  ...       159
# 19991         Single    9978783159  user19992@mail.com  ...       159
# 19994        Married    9142595611  user19995@mail.com  ...       156
# 19999         Single    9951983597  user20000@mail.com  ...       155
#
#       Weight_kg   BMI Smoking_Status  Alcohol_Consumption  Chronic_Condition  \
# 4            87  38.2             No                   No       Hypertension
# 5            85  32.4             No         Occasionally                NaN
# 12           86  31.6             No                   No                NaN
# 15           86  37.2            Yes         Occasionally           Diabetes
# 18           85  30.5             No         Occasionally            Thyroid
# ...         ...   ...            ...                  ...                ...
# 19975        76  32.5             No         Occasionally                NaN
# 19977        79  31.2            Yes         Occasionally           Diabetes
# 19991        85  33.6            Yes         Occasionally            Thyroid
# 19994        77  31.6            Yes                   No       Hypertension
# 19999        89  37.0            Yes         Occasionally             Asthma
#
#        Primary_Doctor_ID   Insurance_Provider Insurance_Policy_No  \
# 4                   D110     Reliance General           POL911663
# 5                   D110        ICICI Lombard           POL589437
# 12                  D102     Reliance General           POL970598
# 15                  D107     Reliance General           POL773678
# 18                  D109  New India Assurance           POL826506
# ...                  ...                  ...                 ...
# 19975               D106  New India Assurance           POL620514
# 19977               D104            HDFC Ergo           POL462578
# 19991               D102        ICICI Lombard           POL329569
# 19994               D109            HDFC Ergo           POL281542
# 19999               D101  New India Assurance           POL666690
#
#       Registration_Date
# 4            2021-12-04
# 5            2022-01-24
# 12           2022-10-01
# 15           2022-10-31
# 18           2024-01-30
# ...                 ...
# 19975        2023-06-17
# 19977        2022-11-21
# 19991        2023-12-03
# 19994        2021-12-02
# 19999        2020-02-18
#
# [4469 rows x 25 columns]

# %% [markdown]
# 23.	Find patients with no chronic condition
#
# 📝 Note: Chronic_Condition value should be "None".

# %%
df[df['Chronic_Condition']=='None']
# Out:
# Empty DataFrame
# Columns: [Patient_ID, First_Name, Last_Name, Gender, Age, Date_of_Birth, Blood_Group, Marital_Status, Contact_Number, Address, City, State, Country, Pincode, Height_cm, Weight_kg, BMI, Smoking_Status, Alcohol_Consumption, Chronic_Condition, Primary_Doctor_ID, Insurance_Provider, Insurance_Policy_No, Registration_Date, Registration_Date_new, Under_weighted, Age_Group, Risk_level, Registration_Month, Registartion_Year, Is_Senior, High_Risk_Patient, BMI_Category, Height_Normalized, Weight_Standardized, Insurance_Status, Patient_Location, high_cardiovascular_risk, lifestyle_counseling, ICU-risk, BMI_Rank_In_City, BMI_Percentile]
# Index: []
#
# [0 rows x 42 columns]

# %% [markdown]
# 24.	Find patients registered after 2023
#
# 📝 Note: Convert Registration_Date to datetime and compare year > 2023.

# %%
df['Registration_Date_new']=pd.to_datetime(df['Registration_Date'])

# %%
df['Registration_Date_new']=df['Registration_Date_new'].dt.year

# %%
df[df['Registration_Date_new']==2023]
# Out:
#       Patient_ID First_Name Last_Name  Gender  Age Date_of_Birth Blood_Group  \
# 0         P00001     Suresh      Iyer    Male   38    1987-11-23          B+
# 1         P00002       Amit    Sharma  Female   38    1987-04-28          B+
# 14        P00015     Suresh     Gupta    Male   50    1975-10-23          B-
# 22        P00023      Pooja     Mehta    Male   56    1969-12-16         AB+
# 26        P00027       Amit     Patil    Male   35    1990-05-07         AB-
# ...          ...        ...       ...     ...  ...           ...         ...
# 19982     P19983      Rohan     Mehta    Male   42    1983-04-13          B+
# 19987     P19988      Rohan     Joshi    Male   46    1979-05-02          B-
# 19988     P19989      Vikas     Patil    Male   54    1971-07-25         AB-
# 19991     P19992      Vikas    Sharma  Female   39    1986-11-17         AB-
# 19998     P19999       Amit    Sharma  Female   43    1982-07-30          A-
#
#       Marital_Status  Phone_Number               Email  ... Weight_kg   BMI  \
# 0             Single    9698790602      user1@mail.com  ...        50  20.8
# 1            Married    9762620912      user2@mail.com  ...        74  26.2
# 14            Single    9498079887     user15@mail.com  ...        75  25.6
# 22           Married    9503854398     user23@mail.com  ...        69  21.5
# 26           Married    9939874149     user27@mail.com  ...        57  18.0
# ...              ...           ...                 ...  ...       ...   ...
# 19982         Single    9143638855  user19983@mail.com  ...        86  28.1
# 19987        Married    9549739409  user19988@mail.com  ...        59  22.2
# 19988        Married    9087089590  user19989@mail.com  ...        59  23.9
# 19991         Single    9978783159  user19992@mail.com  ...        85  33.6
# 19998         Single    9925330649  user19999@mail.com  ...        71  28.8
#
#       Smoking_Status Alcohol_Consumption  Chronic_Condition  \
# 0                Yes        Occasionally            Thyroid
# 1                Yes        Occasionally                NaN
# 14                No                  No            Thyroid
# 22                No        Occasionally       Hypertension
# 26                No        Occasionally             Asthma
# ...              ...                 ...                ...
# 19982             No        Occasionally           Diabetes
# 19987             No                  No                NaN
# 19988             No        Occasionally       Hypertension
# 19991            Yes        Occasionally            Thyroid
# 19998            Yes        Occasionally                NaN
#
#        Primary_Doctor_ID   Insurance_Provider  Insurance_Policy_No  \
# 0                   D110     Reliance General            POL127128
# 1                   D102          Star Health            POL919951
# 14                  D106            HDFC Ergo            POL258655
# 22                  D108          Star Health            POL979936
# 26                  D108          Star Health            POL849460
# ...                  ...                  ...                  ...
# 19982               D100  New India Assurance            POL483547
# 19987               D105            HDFC Ergo            POL189197
# 19988               D103        ICICI Lombard            POL272280
# 19991               D102        ICICI Lombard            POL329569
# 19998               D108        ICICI Lombard            POL531241
#
#       Registration_Date Registration_Date_new
# 0            2023-10-19                  2023
# 1            2023-02-12                  2023
# 14           2023-10-12                  2023
# 22           2023-02-13                  2023
# 26           2023-09-01                  2023
# ...                 ...                   ...
# 19982        2023-03-18                  2023
# 19987        2023-08-05                  2023
# 19988        2023-10-27                  2023
# 19991        2023-12-03                  2023
# 19998        2023-04-02                  2023
#
# [4838 rows x 26 columns]

# %% [markdown]
# 25.	Find patients with blood group O+
#
# 📝 Note: Exact string match "O+".

# %%
df[df['Blood_Group']=='O+']
# Out:
#       Patient_ID First_Name Last_Name  Gender  Age Date_of_Birth Blood_Group  \
# 20        P00021       Neha     Patil  Female   33    1992-01-08          O+
# 23        P00024      Rahul     Patil    Male   31    1994-08-24          O+
# 35        P00036     Anjali     Patil    Male   54    1971-02-24          O+
# 37        P00038     Suresh      Nair  Female   39    1986-02-03          O+
# 45        P00046      Vikas     Joshi    Male   55    1970-10-11          O+
# ...          ...        ...       ...     ...  ...           ...         ...
# 19976     P19977       Amit     Singh  Female   39    1986-05-18          O+
# 19978     P19979     Kavita     Gupta    Male   42    1983-09-27          O+
# 19979     P19980       Amit     Gupta  Female   43    1982-08-17          O+
# 19981     P19982      Vikas     Singh  Female   42    1983-10-27          O+
# 19990     P19991      Vikas     Joshi    Male   55    1970-05-20          O+
#
#       Marital_Status  Contact_Number        Address  ... BMI_Category  \
# 20            Single      9560697611  Local Address  ...       Normal
# 23           Married      9920694229  Local Address  ...   Overweight
# 35            Single      9622342097  Local Address  ...       Normal
# 37            Single      9992549306  Local Address  ...   Overweight
# 45           Married      9078313448  Local Address  ...   Overweight
# ...              ...             ...            ...  ...          ...
# 19976         Single      9499414364  Local Address  ...   Overweight
# 19978        Married      9514834444  Local Address  ...       Normal
# 19979         Single      9312722710  Local Address  ...   Overweight
# 19981         Single      9179699811  Local Address  ...       Normal
# 19990         Single      9551275487  Local Address  ...   Overweight
#
#       Height_Normalized Weight_Standardized  Insurance_Status  \
# 20             1.000000           -0.674330               Yes
# 23             0.300000           -0.420687               Yes
# 35             0.666667           -0.251592               Yes
# 37             0.000000           -1.012520               Yes
# 45             0.233333           -0.674330               Yes
# ...                 ...                 ...               ...
# 19976          0.300000            0.086598               Yes
# 19978          0.433333           -0.505235               Yes
# 19979          0.366667           -0.420687               Yes
# 19981          0.466667           -0.758877               Yes
# 19990          0.333333            0.002050               Yes
#
#                Patient_Location  high_cardiovascular_risk  \
# 20          Mumbai, Maharashtra                     False
# 23            Pune, Maharashtra                     False
# 35          Nashik, Maharashtra                     False
# 37          Mumbai, Maharashtra                     False
# 45            Pune, Maharashtra                     False
# ...                         ...                       ...
# 19976       Nagpur, Maharashtra                     False
# 19978       Nagpur, Maharashtra                     False
# 19979       Nashik, Maharashtra                     False
# 19981  Navi Mumbai, Maharashtra                     False
# 19990       Nagpur, Maharashtra                     False
#
#        lifestyle_counseling ICU-risk BMI_Rank_In_City BMI_Percentile
# 20                     True    False           3575.0         9.4350
# 23                     True    False           2053.0        50.4325
# 35                    False    False           2638.0        34.2250
# 37                     True    False           1900.0        51.0450
# 45                     True    False           2171.0        47.2850
# ...                     ...      ...              ...            ...
# 19976                  True    False           1333.0        66.4275
# 19978                  True    False           2382.0        40.0675
# 19979                  True    False           2136.0        46.5925
# 19981                 False    False           2692.0        30.6725
# 19990                  True    False           1532.0        61.2675
#
# [2410 rows x 42 columns]

# %% [markdown]
# 26.	Find patients insured under Star Health
#
# 📝 Note: Filter Insurance_Provider column.

# %%
df[df['Insurance_Provider']=='Star Health']
# Out:
#       Patient_ID First_Name Last_Name  Gender  Age Date_of_Birth Blood_Group  \
# 1         P00002       Amit    Sharma  Female   38    1987-04-28          B+
# 8         P00009     Kavita     Mehta  Female   30    1995-03-30          A+
# 13        P00014     Suresh     Mehta  Female   39    1986-05-10          A-
# 22        P00023      Pooja     Mehta    Male   56    1969-12-16         AB+
# 26        P00027       Amit     Patil    Male   35    1990-05-07         AB-
# ...          ...        ...       ...     ...  ...           ...         ...
# 19969     P19970     Kavita  Kulkarni    Male   39    1986-09-11          A+
# 19980     P19981     Kavita     Singh  Female   40    1985-01-07          B-
# 19989     P19990      Pooja     Joshi    Male   35    1990-07-24         AB-
# 19992     P19993      Rahul      Iyer  Female   58    1967-01-17         AB-
# 19997     P19998     Anjali     Singh  Female   46    1979-01-16          A-
#
#       Marital_Status  Contact_Number        Address  ... BMI_Category  \
# 1            Married      9762620912  Local Address  ...   Overweight
# 8            Married      9853397700  Local Address  ...   Overweight
# 13           Married      9240144188  Local Address  ...   Overweight
# 22           Married      9503854398  Local Address  ...       Normal
# 26           Married      9939874149  Local Address  ...  Underweight
# ...              ...             ...            ...  ...          ...
# 19969        Married      9778593560  Local Address  ...       Normal
# 19980        Married      9467940100  Local Address  ...   Overweight
# 19989        Married      9823010533  Local Address  ...  Underweight
# 19992         Single      9138504573  Local Address  ...       Normal
# 19997        Married      9852974113  Local Address  ...       Normal
#
#       Height_Normalized Weight_Standardized  Insurance_Status  \
# 1              0.600000            0.340240               Yes
# 8              0.166667           -0.167045               Yes
# 13             0.500000            0.509335               Yes
# 22             0.966667           -0.082497               Yes
# 26             0.933333           -1.097067               Yes
# ...                 ...                 ...               ...
# 19969          0.200000           -1.519805               Yes
# 19980          0.433333            0.340240               Yes
# 19989          0.933333           -1.266162               Yes
# 19992          0.800000           -0.589782               Yes
# 19997          0.566667           -1.266162               Yes
#
#                Patient_Location  high_cardiovascular_risk  \
# 1           Mumbai, Maharashtra                     False
# 8      Navi Mumbai, Maharashtra                     False
# 13     Navi Mumbai, Maharashtra                     False
# 22            Pune, Maharashtra                     False
# 26          Mumbai, Maharashtra                     False
# ...                         ...                       ...
# 19969       Nashik, Maharashtra                     False
# 19980       Nashik, Maharashtra                     False
# 19989       Mumbai, Maharashtra                     False
# 19992  Navi Mumbai, Maharashtra                     False
# 19997       Nagpur, Maharashtra                     False
#
#        lifestyle_counseling ICU-risk BMI_Rank_In_City BMI_Percentile
# 1                      True    False           1793.0        53.8275
# 8                      True    False           1277.0        67.4250
# 13                     True    False           1357.0        65.2025
# 22                     True    False           3164.0        22.7700
# 26                     True    False           3752.0         4.8875
# ...                     ...      ...              ...            ...
# 19969                  True    False           3137.0        22.0825
# 19980                  True    False           1380.0        65.2025
# 19989                  True    False           3822.0         2.9900
# 19992                 False    False           3186.0        18.4125
# 19997                  True    False           3520.0        12.3325
#
# [4036 rows x 42 columns]

# %% [markdown]
# 27.	Find patients whose height is above 175 cm
#
# 📝 Note: Numeric filtering using Height_cm column.

# %%
df[df['Height_cm']>175]
# Out:
#       Patient_ID First_Name Last_Name  Gender  Age Date_of_Birth Blood_Group  \
# 6         P00007     Suresh      Nair    Male   42    1983-02-17          B-
# 10        P00011      Sneha     Verma  Female   51    1974-03-31          O-
# 16        P00017       Neha     Gupta  Female   37    1988-05-03          B-
# 20        P00021       Neha     Patil  Female   33    1992-01-08          O+
# 22        P00023      Pooja     Mehta    Male   56    1969-12-16         AB+
# ...          ...        ...       ...     ...  ...           ...         ...
# 19953     P19954      Sneha      Iyer    Male   55    1970-10-26          A-
# 19959     P19960      Pooja     Mehta  Female   53    1972-05-08          O-
# 19984     P19985       Amit     Mehta  Female   30    1995-03-25          O-
# 19985     P19986     Anjali     Mehta    Male   46    1979-05-15         AB+
# 19989     P19990      Pooja     Joshi    Male   35    1990-07-24         AB-
#
#       Marital_Status  Contact_Number        Address  ... BMI_Category  \
# 6             Single      9199546251  Local Address  ...   Overweight
# 10            Single      9227251578  Local Address  ...   Overweight
# 16            Single      9625970283  Local Address  ...  Underweight
# 20            Single      9560697611  Local Address  ...       Normal
# 22           Married      9503854398  Local Address  ...       Normal
# ...              ...             ...            ...  ...          ...
# 19953        Married      9207604119  Local Address  ...       Normal
# 19959         Single      9104002737  Local Address  ...       Normal
# 19984         Single      9569006453  Local Address  ...  Underweight
# 19985         Single      9010102699  Local Address  ...       Normal
# 19989        Married      9823010533  Local Address  ...  Underweight
#
#       Height_Normalized Weight_Standardized  Insurance_Status  \
# 6              0.866667            1.523905               Yes
# 10             1.000000            1.608453               Yes
# 16             0.900000           -1.519805               Yes
# 20             1.000000           -0.674330               Yes
# 22             0.966667           -0.082497               Yes
# ...                 ...                 ...               ...
# 19953          0.900000            0.002050               Yes
# 19959          1.000000            0.255693               Yes
# 19984          0.933333           -1.181615               Yes
# 19985          0.866667           -0.420687               Yes
# 19989          0.933333           -1.266162               Yes
#
#                Patient_Location  high_cardiovascular_risk  \
# 6             Pune, Maharashtra                     False
# 10            Pune, Maharashtra                     False
# 16            Pune, Maharashtra                     False
# 20          Mumbai, Maharashtra                     False
# 22            Pune, Maharashtra                     False
# ...                         ...                       ...
# 19953       Nashik, Maharashtra                     False
# 19959  Navi Mumbai, Maharashtra                     False
# 19984       Nagpur, Maharashtra                     False
# 19985  Navi Mumbai, Maharashtra                     False
# 19989       Mumbai, Maharashtra                     False
#
#        lifestyle_counseling ICU-risk BMI_Rank_In_City BMI_Percentile
# 6                      True    False           1296.0        68.3025
# 10                     True    False           1537.0        62.6025
# 16                     True    False           4029.0         1.2525
# 20                     True    False           3575.0         9.4350
# 22                     True    False           3164.0        22.7700
# ...                     ...      ...              ...            ...
# 19953                  True    False           2886.0        28.2650
# 19959                  True    False           2734.0        29.4375
# 19984                  True    False           3882.0         3.8575
# 19985                  True    False           3128.0        19.5950
# 19989                  True    False           3822.0         2.9900
#
# [3200 rows x 42 columns]

# %% [markdown]
# 28.	Find patients aged between 30 and 45
#
# 📝 Note: Age >= 30 AND Age <= 45.

# %%
df[(df['Age']>=30) & (df['Age']<=45)]
# Out:
#       Patient_ID First_Name Last_Name  Gender  Age Date_of_Birth Blood_Group  \
# 0         P00001     Suresh      Iyer    Male   38    1987-11-23          B+
# 1         P00002       Amit    Sharma  Female   38    1987-04-28          B+
# 4         P00005      Rohan     Verma    Male   41    1984-02-11          A-
# 6         P00007     Suresh      Nair    Male   42    1983-02-17          B-
# 8         P00009     Kavita     Mehta  Female   30    1995-03-30          A+
# ...          ...        ...       ...     ...  ...           ...         ...
# 19989     P19990      Pooja     Joshi    Male   35    1990-07-24         AB-
# 19991     P19992      Vikas    Sharma  Female   39    1986-11-17         AB-
# 19993     P19994     Anjali     Joshi  Female   43    1982-04-25          O-
# 19995     P19996     Anjali     Mehta    Male   36    1989-10-07          A-
# 19998     P19999       Amit    Sharma  Female   43    1982-07-30          A-
#
#       Marital_Status  Phone_Number               Email  ... Weight_kg   BMI  \
# 0             Single    9698790602      user1@mail.com  ...        50  20.8
# 1            Married    9762620912      user2@mail.com  ...        74  26.2
# 4             Single    9644918514      user5@mail.com  ...        87  38.2
# 6             Single    9199546251      user7@mail.com  ...        88  28.4
# 8            Married    9853397700      user9@mail.com  ...        68  28.3
# ...              ...           ...                 ...  ...       ...   ...
# 19989        Married    9823010533  user19990@mail.com  ...        55  17.4
# 19991         Single    9978783159  user19992@mail.com  ...        85  33.6
# 19993        Married    9864695122  user19994@mail.com  ...        62  20.7
# 19995         Single    9990287038  user19996@mail.com  ...        63  21.0
# 19998         Single    9925330649  user19999@mail.com  ...        71  28.8
#
#       Smoking_Status Alcohol_Consumption  Chronic_Condition  \
# 0                Yes        Occasionally            Thyroid
# 1                Yes        Occasionally                NaN
# 4                 No                  No       Hypertension
# 6                Yes                  No                NaN
# 8                Yes                  No             Asthma
# ...              ...                 ...                ...
# 19989            Yes        Occasionally           Diabetes
# 19991            Yes        Occasionally            Thyroid
# 19993             No        Occasionally           Diabetes
# 19995             No        Occasionally       Hypertension
# 19998            Yes        Occasionally                NaN
#
#        Primary_Doctor_ID  Insurance_Provider  Insurance_Policy_No  \
# 0                   D110    Reliance General            POL127128
# 1                   D102         Star Health            POL919951
# 4                   D110    Reliance General            POL911663
# 6                   D108    Reliance General            POL682287
# 8                   D103         Star Health            POL233712
# ...                  ...                 ...                  ...
# 19989               D108         Star Health            POL229492
# 19991               D102       ICICI Lombard            POL329569
# 19993               D109    Reliance General            POL507705
# 19995               D108       ICICI Lombard            POL308290
# 19998               D108       ICICI Lombard            POL531241
#
#       Registration_Date Registration_Date_new
# 0            2023-10-19                  2023
# 1            2023-02-12                  2023
# 4            2021-12-04                  2021
# 6            2020-03-22                  2020
# 8            2020-10-24                  2020
# ...                 ...                   ...
# 19989        2022-07-08                  2022
# 19991        2023-12-03                  2023
# 19993        2020-07-05                  2020
# 19995        2021-07-03                  2021
# 19998        2023-04-02                  2023
#
# [9756 rows x 26 columns]

# %% [markdown]
# 29.	Find patients from Mumbai OR Pune
#
# 📝 Note: Use OR condition or isin().

# %%
df[(df['City'] == 'Mumbai') | (df['City'] == 'Pune')]
# Out:
#       Patient_ID First_Name Last_Name  Gender  Age Date_of_Birth Blood_Group  \
# 1         P00002       Amit    Sharma  Female   38    1987-04-28          B+
# 3         P00004     Anjali     Patil    Male   47    1978-12-04          A-
# 6         P00007     Suresh      Nair    Male   42    1983-02-17          B-
# 7         P00008      Vikas     Gupta  Female   59    1966-03-23         AB+
# 10        P00011      Sneha     Verma  Female   51    1974-03-31          O-
# ...          ...        ...       ...     ...  ...           ...         ...
# 19987     P19988      Rohan     Joshi    Male   46    1979-05-02          B-
# 19988     P19989      Vikas     Patil    Male   54    1971-07-25         AB-
# 19989     P19990      Pooja     Joshi    Male   35    1990-07-24         AB-
# 19991     P19992      Vikas    Sharma  Female   39    1986-11-17         AB-
# 19993     P19994     Anjali     Joshi  Female   43    1982-04-25          O-
#
#       Marital_Status  Contact_Number        Address  ... BMI_Category  \
# 1            Married      9762620912  Local Address  ...   Overweight
# 3            Married      9196136323  Local Address  ...       Normal
# 6             Single      9199546251  Local Address  ...   Overweight
# 7            Married      9000565982  Local Address  ...       Normal
# 10            Single      9227251578  Local Address  ...   Overweight
# ...              ...             ...            ...  ...          ...
# 19987        Married      9549739409  Local Address  ...       Normal
# 19988        Married      9087089590  Local Address  ...       Normal
# 19989        Married      9823010533  Local Address  ...  Underweight
# 19991         Single      9978783159  Local Address  ...        Obese
# 19993        Married      9864695122  Local Address  ...       Normal
#
#       Height_Normalized Weight_Standardized  Insurance_Status  \
# 1              0.600000            0.340240               Yes
# 3              0.400000           -0.843425               Yes
# 6              0.866667            1.523905               Yes
# 7              0.766667           -0.843425               Yes
# 10             1.000000            1.608453               Yes
# ...                 ...                 ...               ...
# 19987          0.433333           -0.927972               Yes
# 19988          0.233333           -0.927972               Yes
# 19989          0.933333           -1.266162               Yes
# 19991          0.300000            1.270263               Yes
# 19993          0.766667           -0.674330               Yes
#
#           Patient_Location  high_cardiovascular_risk  lifestyle_counseling  \
# 1      Mumbai, Maharashtra                     False                  True
# 3      Mumbai, Maharashtra                     False                 False
# 6        Pune, Maharashtra                     False                  True
# 7        Pune, Maharashtra                     False                  True
# 10       Pune, Maharashtra                     False                  True
# ...                    ...                       ...                   ...
# 19987    Pune, Maharashtra                     False                 False
# 19988    Pune, Maharashtra                     False                  True
# 19989  Mumbai, Maharashtra                     False                  True
# 19991  Mumbai, Maharashtra                     False                  True
# 19993  Mumbai, Maharashtra                     False                  True
#
#       ICU-risk BMI_Rank_In_City BMI_Percentile
# 1        False           1793.0        53.8275
# 3        False           2659.0        32.1975
# 6        False           1296.0        68.3025
# 7        False           3511.0        13.9500
# 10       False           1537.0        62.6025
# ...        ...              ...            ...
# 19987    False           2965.0        27.6075
# 19988    False           2520.0        38.6975
# 19989    False           3822.0         2.9900
# 19991    False            341.0        90.9850
# 19993    False           3234.0        17.7775
#
# [8021 rows x 42 columns]

# %% [markdown]
# 30.	Find patients who are married and diabetic
#
# 📝 Note: Marital_Status = Married AND Chronic_Condition = Diabetes.

# %%
df[(df['Marital_Status']=='Married') & (df['Chronic_Condition'] == 'Diabetes')]
# Out:
#       Patient_ID First_Name Last_Name  Gender  Age Date_of_Birth Blood_Group  \
# 3         P00004     Anjali     Patil    Male   47    1978-12-04          A-
# 13        P00014     Suresh     Mehta  Female   39    1986-05-10          A-
# 15        P00016      Pooja      Iyer    Male   41    1984-04-04         AB-
# 30        P00031      Vikas     Patil    Male   46    1979-10-08          O-
# 34        P00035       Amit      Nair    Male   46    1979-02-01          O-
# ...          ...        ...       ...     ...  ...           ...         ...
# 19953     P19954      Sneha      Iyer    Male   55    1970-10-26          A-
# 19977     P19978      Rahul     Gupta    Male   43    1982-07-27         AB-
# 19983     P19984      Rahul      Iyer  Female   54    1971-07-06          A+
# 19989     P19990      Pooja     Joshi    Male   35    1990-07-24         AB-
# 19993     P19994     Anjali     Joshi  Female   43    1982-04-25          O-
#
#       Marital_Status  Phone_Number               Email  ... Weight_kg   BMI  \
# 3            Married    9196136323      user4@mail.com  ...        60  22.9
# 13           Married    9240144188     user14@mail.com  ...        76  27.9
# 15           Married    9131640457     user16@mail.com  ...        86  37.2
# 30           Married    9558075342     user31@mail.com  ...        51  21.5
# 34           Married    9924224974     user35@mail.com  ...        78  25.8
# ...              ...           ...                 ...  ...       ...   ...
# 19953        Married    9207604119  user19954@mail.com  ...        70  22.3
# 19977        Married    9402505693  user19978@mail.com  ...        79  31.2
# 19983        Married    9242052517  user19984@mail.com  ...        55  18.2
# 19989        Married    9823010533  user19990@mail.com  ...        55  17.4
# 19993        Married    9864695122  user19994@mail.com  ...        62  20.7
#
#       Smoking_Status Alcohol_Consumption  Chronic_Condition  \
# 3                 No                  No           Diabetes
# 13               Yes                  No           Diabetes
# 15               Yes        Occasionally           Diabetes
# 30                No        Occasionally           Diabetes
# 34                No        Occasionally           Diabetes
# ...              ...                 ...                ...
# 19953            Yes                  No           Diabetes
# 19977            Yes        Occasionally           Diabetes
# 19983            Yes                  No           Diabetes
# 19989            Yes        Occasionally           Diabetes
# 19993             No        Occasionally           Diabetes
#
#        Primary_Doctor_ID   Insurance_Provider  Insurance_Policy_No  \
# 3                   D101     Reliance General            POL912134
# 13                  D102          Star Health            POL980183
# 15                  D107     Reliance General            POL773678
# 30                  D109          Star Health            POL496551
# 34                  D109          Star Health            POL338388
# ...                  ...                  ...                  ...
# 19953               D107     Reliance General            POL230841
# 19977               D104            HDFC Ergo            POL462578
# 19983               D102  New India Assurance            POL778154
# 19989               D108          Star Health            POL229492
# 19993               D109     Reliance General            POL507705
#
#       Registration_Date Registration_Date_new
# 3            2020-05-17                  2020
# 13           2022-12-17                  2022
# 15           2022-10-31                  2022
# 30           2020-02-26                  2020
# 34           2023-10-26                  2023
# ...                 ...                   ...
# 19953        2022-06-22                  2022
# 19977        2022-11-21                  2022
# 19983        2021-12-26                  2021
# 19989        2022-07-08                  2022
# 19993        2020-07-05                  2020
#
# [2015 rows x 26 columns]

# %% [markdown]
# 31.	Find patients whose email contains “gmail”
#
# 📝 Note: Use string methods for partial match.

# %%
df[df['Email'].str.contains('gmail', case=False , na=False)]
# Out:
# Empty DataFrame
# Columns: [Patient_ID, First_Name, Last_Name, Gender, Age, Date_of_Birth, Blood_Group, Marital_Status, Phone_Number, Email, Address, City, State, Country, Pincode, Height_cm, Weight_kg, BMI, Smoking_Status, Alcohol_Consumption, Chronic_Condition, Primary_Doctor_ID, Insurance_Provider, Insurance_Policy_No, Registration_Date]
# Index: []
#
# [0 rows x 25 columns]

# %% [markdown]
# 32.	Find patients whose Patient_ID starts with “P1”
#
# 📝 Note: Prefix-based filtering.

# %%
df[df['Patient_ID'].str.contains('P1')]
# Out:
#       Patient_ID First_Name Last_Name  Gender  Age Date_of_Birth Blood_Group  \
# 9999      P10000      Vikas    Sharma    Male   53    1972-09-06          B+
# 10000     P10001     Anjali     Singh  Female   51    1974-04-11          A+
# 10001     P10002     Anjali     Singh  Female   56    1969-05-19          B+
# 10002     P10003       Amit  Kulkarni    Male   38    1987-07-10          A-
# 10003     P10004      Pooja      Nair    Male   46    1979-07-20         AB+
# ...          ...        ...       ...     ...  ...           ...         ...
# 19994     P19995     Suresh     Singh    Male   58    1967-01-14         AB+
# 19995     P19996     Anjali     Mehta    Male   36    1989-10-07          A-
# 19996     P19997      Vikas     Verma  Female   57    1968-10-05         AB-
# 19997     P19998     Anjali     Singh  Female   46    1979-01-16          A-
# 19998     P19999       Amit    Sharma  Female   43    1982-07-30          A-
#
#       Marital_Status  Phone_Number               Email  ... Height_cm  \
# 9999         Married    9422488565  user10000@mail.com  ...       153
# 10000         Single    9035400570  user10001@mail.com  ...       168
# 10001         Single    9248354863  user10002@mail.com  ...       150
# 10002         Single    9523763075  user10003@mail.com  ...       173
# 10003        Married    9702294516  user10004@mail.com  ...       152
# ...              ...           ...                 ...  ...       ...
# 19994        Married    9142595611  user19995@mail.com  ...       156
# 19995         Single    9990287038  user19996@mail.com  ...       173
# 19996         Single    9498150434  user19997@mail.com  ...       174
# 19997        Married    9852974113  user19998@mail.com  ...       167
# 19998         Single    9925330649  user19999@mail.com  ...       157
#
#       Weight_kg   BMI Smoking_Status  Alcohol_Consumption  Chronic_Condition  \
# 9999         78  33.3            Yes                   No             Asthma
# 10000        82  29.1            Yes         Occasionally       Hypertension
# 10001        90  40.0             No         Occasionally            Thyroid
# 10002        60  20.0             No         Occasionally            Thyroid
# 10003        51  22.1             No         Occasionally             Asthma
# ...         ...   ...            ...                  ...                ...
# 19994        77  31.6            Yes                   No       Hypertension
# 19995        63  21.0             No         Occasionally       Hypertension
# 19996        61  20.1            Yes         Occasionally       Hypertension
# 19997        55  19.7             No         Occasionally                NaN
# 19998        71  28.8            Yes         Occasionally                NaN
#
#        Primary_Doctor_ID   Insurance_Provider Insurance_Policy_No  \
# 9999                D110          Star Health           POL199160
# 10000               D105     Reliance General           POL124664
# 10001               D101     Reliance General           POL280028
# 10002               D107  New India Assurance           POL954684
# 10003               D102        ICICI Lombard           POL788093
# ...                  ...                  ...                 ...
# 19994               D109            HDFC Ergo           POL281542
# 19995               D108        ICICI Lombard           POL308290
# 19996               D102  New India Assurance           POL513474
# 19997               D105          Star Health           POL129135
# 19998               D108        ICICI Lombard           POL531241
#
#       Registration_Date
# 9999         2022-12-31
# 10000        2021-06-12
# 10001        2020-12-29
# 10002        2020-01-05
# 10003        2021-06-07
# ...                 ...
# 19994        2021-12-02
# 19995        2021-07-03
# 19996        2024-01-18
# 19997        2020-03-02
# 19998        2023-04-02
#
# [10000 rows x 25 columns]

# %% [markdown]
# 33.	Find patients with weight above average weight
#
# 📝 Note: First calculate average weight, then filter.

# %%
df.groupby('Gender')['Weight_kg'].mean()
# Out:
# Gender
# Female    69.975147
# Male      69.976336
# Name: Weight_kg, dtype: float64

# %% [markdown]
# 34.	Find patients having Asthma or Thyroid
#
# 📝 Note: OR condition on Chronic_Condition column.

# %%
df[(df['Chronic_Condition']=='Asthma') | (df['Chronic_Condition']=='Thyroid')]
# Out:
#       Patient_ID First_Name Last_Name  Gender  Age Date_of_Birth Blood_Group  \
# 0         P00001     Suresh      Iyer    Male   38    1987-11-23          B+
# 2         P00003       Neha     Joshi    Male   56    1969-12-29         AB-
# 8         P00009     Kavita     Mehta  Female   30    1995-03-30          A+
# 11        P00012      Rahul     Mehta  Female   50    1975-11-26         AB-
# 14        P00015     Suresh     Gupta    Male   50    1975-10-23          B-
# ...          ...        ...       ...     ...  ...           ...         ...
# 19978     P19979     Kavita     Gupta    Male   42    1983-09-27          O+
# 19981     P19982      Vikas     Singh  Female   42    1983-10-27          O+
# 19990     P19991      Vikas     Joshi    Male   55    1970-05-20          O+
# 19991     P19992      Vikas    Sharma  Female   39    1986-11-17         AB-
# 19999     P20000      Pooja     Gupta  Female   58    1967-02-17          O-
#
#       Marital_Status  Phone_Number               Email  ... Height_cm  \
# 0             Single    9698790602      user1@mail.com  ...       155
# 2             Single    9522528550      user3@mail.com  ...       169
# 8            Married    9853397700      user9@mail.com  ...       155
# 11           Married    9380410557     user12@mail.com  ...       170
# 14            Single    9498079887     user15@mail.com  ...       171
# ...              ...           ...                 ...  ...       ...
# 19978        Married    9514834444  user19979@mail.com  ...       163
# 19981         Single    9179699811  user19982@mail.com  ...       164
# 19990         Single    9551275487  user19991@mail.com  ...       160
# 19991         Single    9978783159  user19992@mail.com  ...       159
# 19999         Single    9951983597  user20000@mail.com  ...       155
#
#       Weight_kg   BMI Smoking_Status  Alcohol_Consumption  Chronic_Condition  \
# 0            50  20.8            Yes         Occasionally            Thyroid
# 2            71  24.9             No                   No            Thyroid
# 8            68  28.3            Yes                   No             Asthma
# 11           82  28.4             No         Occasionally             Asthma
# 14           75  25.6             No                   No            Thyroid
# ...         ...   ...            ...                  ...                ...
# 19978        64  24.1             No         Occasionally            Thyroid
# 19981        61  22.7             No                   No            Thyroid
# 19990        70  27.3            Yes                   No            Thyroid
# 19991        85  33.6            Yes         Occasionally            Thyroid
# 19999        89  37.0            Yes         Occasionally             Asthma
#
#        Primary_Doctor_ID   Insurance_Provider Insurance_Policy_No  \
# 0                   D110     Reliance General           POL127128
# 2                   D109  New India Assurance           POL924889
# 8                   D103          Star Health           POL233712
# 11                  D110     Reliance General           POL684731
# 14                  D106            HDFC Ergo           POL258655
# ...                  ...                  ...                 ...
# 19978               D109     Reliance General           POL399622
# 19981               D107     Reliance General           POL112807
# 19990               D108  New India Assurance           POL934323
# 19991               D102        ICICI Lombard           POL329569
# 19999               D101  New India Assurance           POL666690
#
#       Registration_Date
# 0            2023-10-19
# 2            2020-07-25
# 8            2020-10-24
# 11           2022-12-15
# 14           2023-10-12
# ...                 ...
# 19978        2020-03-14
# 19981        2021-09-22
# 19990        2020-05-26
# 19991        2023-12-03
# 19999        2020-02-18
#
# [8012 rows x 25 columns]

# %% [markdown]
# 35.	Find patients whose BMI is below 18.5
#
# 📝 Note: BMI < 18.5 indicates underweight.

# %%
df['Under_weighted']=df['BMI']<18.5
df['Under_weighted']
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 19995    False
# 19996    False
# 19997    False
# 19998    False
# 19999    False
# Name: Under_weighted, Length: 20000, dtype: bool

# %% [markdown]
# **SECTION 3: AGGREGATION & GROUPBY (36–55)**
#
# 36.	Find the average age of patients
#
# 📝 Note: Use mean aggregation on Age column.

# %%
df.groupby('Age')['Age'].mean()
# Out:
# Age
# 27    27.0
# 28    28.0
# 29    29.0
# 30    30.0
# 31    31.0
# 32    32.0
# 33    33.0
# 34    34.0
# 35    35.0
# 36    36.0
# 37    37.0
# 38    38.0
# 39    39.0
# 40    40.0
# 41    41.0
# 42    42.0
# 43    43.0
# 44    44.0
# 45    45.0
# 46    46.0
# 47    47.0
# 48    48.0
# 49    49.0
# 50    50.0
# 51    51.0
# 52    52.0
# 53    53.0
# 54    54.0
# 55    55.0
# 56    56.0
# 57    57.0
# 58    58.0
# 59    59.0
# 60    60.0
# Name: Age, dtype: float64

# %% [markdown]
# 37.	Find average BMI by gender
#
# 📝 Note: Group by Gender and calculate mean BMI.

# %%
df.groupby('Gender')['BMI'].mean()
# Out:
# Gender
# Female    25.939014
# Male      25.915914
# Name: BMI, dtype: float64

# %% [markdown]
# 38.	Count number of patients per city
#
# 📝 Note: Group by City and count rows.

# %%
df.groupby('City')['Patient_ID'].count()
# Out:
# City
# Mumbai         3922
# Nagpur         4042
# Nashik         4032
# Navi Mumbai    3905
# Pune           4099
# Name: Patient_ID, dtype: int64

# %% [markdown]
# 39.	Count number of patients per chronic condition
#
# 📝 Note: Shows disease distribution.

# %%
df.groupby('Chronic_Condition')['Patient_ID'].count()
# Out:
# Chronic_Condition
# Asthma          3998
# Diabetes        4014
# Hypertension    3965
# Thyroid         4014
# Name: Patient_ID, dtype: int64

# %% [markdown]
# 40.	Find maximum age per city
#
# 📝 Note: Group by City and apply max on Age.

# %%
df.groupby('City')['Age'].max()
# Out:
# City
# Mumbai         60
# Nagpur         60
# Nashik         60
# Navi Mumbai    60
# Pune           60
# Name: Age, dtype: int64

# %% [markdown]
# 41.	Find minimum BMI per gender
# 📝 Note: Identify lowest BMI per gender group.

# %%
df.groupby('Gender')['BMI'].min()
# Out:
# Gender
# Female    15.4
# Male      15.4
# Name: BMI, dtype: float64

# %% [markdown]
# 42.	Find average height per city
#
# 📝 Note: City-wise physical comparison.

# %%
df.groupby('City')['Height_cm'].mean()
# Out:
# City
# Mumbai         164.782764
# Nagpur         165.090549
# Nashik         165.035218
# Navi Mumbai    165.071191
# Pune           165.030007
# Name: Height_cm, dtype: float64

# %% [markdown]
# 43.	Find total patients per insurance provider
#
# 📝 Note: Count patients under each insurer.

# %%
df.groupby('Insurance_Provider')['Patient_ID'].count()
# Out:
# Insurance_Provider
# HDFC Ergo              3942
# ICICI Lombard          3969
# New India Assurance    4077
# Reliance General       3976
# Star Health            4036
# Name: Patient_ID, dtype: int64

# %% [markdown]
# 44.	Find city with highest number of patients
#
# 📝 Note: Sort aggregated counts.

# %%
df.groupby('City')['Patient_ID'].count().sort_values(ascending=False)
# Out:
# City
# Pune           4099
# Nagpur         4042
# Nashik         4032
# Mumbai         3922
# Navi Mumbai    3905
# Name: Patient_ID, dtype: int64

# %% [markdown]
# 45.	Find average BMI per smoking status
#
# 📝 Note: Compare smokers vs non-smokers.

# %%
df.groupby('Smoking_Status')['BMI'].mean()
# Out:
# Smoking_Status
# No     25.918135
# Yes    25.936532
# Name: BMI, dtype: float64

# %% [markdown]
# 46.	Find number of patients per blood group
#
# 📝 Note: Useful for healthcare planning.

# %%
df.groupby('Blood_Group')['Patient_ID'].count()
# Out:
# Blood_Group
# A+     2590
# A-     2493
# AB+    2565
# AB-    2417
# B+     2521
# B-     2505
# O+     2410
# O-     2499
# Name: Patient_ID, dtype: int64

# %% [markdown]
# 47.	Find average age per marital status
#
# 📝 Note: Demographic insight.

# %%
df.groupby('Marital_Status')['Age'].mean()
# Out:
# Marital_Status
# Married    43.895618
# Single     43.869951
# Name: Age, dtype: float64

# %% [markdown]
# 48.	Find highest BMI per chronic condition
#
# 📝 Note: Identify extreme risk cases.

# %%
df.groupby('Chronic_Condition')['BMI'].max()
# Out:
# Chronic_Condition
# Asthma          40.0
# Diabetes        40.0
# Hypertension    40.0
# Thyroid         40.0
# Name: BMI, dtype: float64

# %% [markdown]
# 49.	Find lowest weight per city
#
# 📝 Note: Detect outliers.

# %%
df.groupby('City')['Weight_kg'].min()
# Out:
# City
# Mumbai         50
# Nagpur         50
# Nashik         50
# Navi Mumbai    50
# Pune           50
# Name: Weight_kg, dtype: int64

# %% [markdown]
# 50.	Count patients registered per year
#
# 📝 Note: Extract year from Registration_Date.

# %%
df['Registration_Date'] = pd.to_datetime(df['Registration_Date'])

# %%
df['Registration_Date'].dt.year.value_counts().sort_index()
# Out:
# Registration_Date
# 2020    4944
# 2021    4811
# 2022    4837
# 2023    4838
# 2024     570
# Name: count, dtype: int64

# %% [markdown]
# 51.	Find insurance provider with maximum patients
#
# 📝 Note: Rank insurance providers.

# %%
df.groupby('Insurance_Provider')['Patient_ID'].count().sort_values(ascending=False)
# Out:
# Insurance_Provider
# New India Assurance    4077
# Star Health            4036
# Reliance General       3976
# ICICI Lombard          3969
# HDFC Ergo              3942
# Name: Patient_ID, dtype: int64

# %% [markdown]
# 52.	Find number of patients per doctor
#
# 📝 Note: Doctor workload analysis

# %%
df.groupby('Primary_Doctor_ID')['Patient_ID'].count()
# Out:
# Primary_Doctor_ID
# D100    1821
# D101    1789
# D102    1841
# D103    1846
# D104    1820
# D105    1809
# D106    1733
# D107    1857
# D108    1852
# D109    1806
# D110    1826
# Name: Patient_ID, dtype: int64

# %% [markdown]
# 53.	Find average BMI per doctor
#
# 📝 Note: Care quality insight

# %%
df.groupby('Primary_Doctor_ID')['BMI'].mean()
# Out:
# Primary_Doctor_ID
# D100    25.969577
# D101    25.832700
# D102    26.107496
# D103    26.128277
# D104    25.819615
# D105    25.869707
# D106    25.856145
# D107    25.877975
# D108    26.002376
# D109    25.864673
# D110    25.860843
# Name: BMI, dtype: float64

# %% [markdown]
# 54.	Find total patients with chronic conditions
#
# 📝 Note: Exclude "None".

# %%
df.groupby('Chronic_Condition')['Patient_ID'].count()
# Out:
# Chronic_Condition
# Asthma          3998
# Diabetes        4014
# Hypertension    3965
# Thyroid         4014
# Name: Patient_ID, dtype: int64

# %% [markdown]
# 55.	Find percentage of smokers vs non-smokers
#
# 📝 Note: Convert counts into percentages.

# %%
smoker= df['Smoking_Status'].value_counts(normalize=True)* 100
smoker
# Out:
# Smoking_Status
# No     50.18
# Yes    49.82
# Name: proportion, dtype: float64

# %% [markdown]
# **SECTION 4: DATA TRANSFORMATION (56–75)**

# %% [markdown]
# 56.	Create a new column Age_Group (Young, Adult, Senior)
#
# 📝 Note:
#
# o	Age 5–25 → Young
#
# o	Age 26–50 → Adult
#
# o	Age Above 50 → Senior

# %%
df['Age_Group']=df['Age'].apply(lambda i:'Young' if i>=5 and i<=25
                                       else ('Adult' if i>=26 and i<=50
                                       else 'Senior'))
df['Age_Group']
# Out:
# 0         Adult
# 1         Adult
# 2        Senior
# 3         Adult
# 4         Adult
#           ...
# 19995     Adult
# 19996    Senior
# 19997     Adult
# 19998     Adult
# 19999    Senior
# Name: Age_Group, Length: 20000, dtype: object

# %% [markdown]
# 57.	Create a column Risk_Level based on BMI
#
# 📝 Note:
#
# o	BMI < 18.5 → Low
#
# o	BMI 18.5–25 → Normal
#
# o	BMI 25–30 → Medium
#
# o	BMI > 30 → High

# %%
df['Risk_level']=df['BMI'].apply(lambda i:'Low' if i<18.5 else ('Normal' if i<=25 else ('Medium' if i<=30 else 'High')))
df['Risk_level']
# Out:
# 0        Normal
# 1        Medium
# 2        Normal
# 3        Normal
# 4          High
#           ...
# 19995    Normal
# 19996    Normal
# 19997    Normal
# 19998    Medium
# 19999      High
# Name: Risk_level, Length: 20000, dtype: object

# %% [markdown]
# 58.	Convert Registration_Date to datetime
#
# 📝 Note: Required before extracting year or month

# %%
df['Registration_Month']=pd.to_datetime(df['Registration_Date']).dt.month
df
# Out:
#       Patient_ID First_Name Last_Name  Gender  Age Date_of_Birth Blood_Group  \
# 0         P00001     Suresh      Iyer    Male   38    1987-11-23          B+
# 1         P00002       Amit    Sharma  Female   38    1987-04-28          B+
# 2         P00003       Neha     Joshi    Male   56    1969-12-29         AB-
# 3         P00004     Anjali     Patil    Male   47    1978-12-04          A-
# 4         P00005      Rohan     Verma    Male   41    1984-02-11          A-
# ...          ...        ...       ...     ...  ...           ...         ...
# 19995     P19996     Anjali     Mehta    Male   36    1989-10-07          A-
# 19996     P19997      Vikas     Verma  Female   57    1968-10-05         AB-
# 19997     P19998     Anjali     Singh  Female   46    1979-01-16          A-
# 19998     P19999       Amit    Sharma  Female   43    1982-07-30          A-
# 19999     P20000      Pooja     Gupta  Female   58    1967-02-17          O-
#
#       Marital_Status  Phone_Number               Email  ... Chronic_Condition  \
# 0             Single    9698790602      user1@mail.com  ...           Thyroid
# 1            Married    9762620912      user2@mail.com  ...               NaN
# 2             Single    9522528550      user3@mail.com  ...           Thyroid
# 3            Married    9196136323      user4@mail.com  ...          Diabetes
# 4             Single    9644918514      user5@mail.com  ...      Hypertension
# ...              ...           ...                 ...  ...               ...
# 19995         Single    9990287038  user19996@mail.com  ...      Hypertension
# 19996         Single    9498150434  user19997@mail.com  ...      Hypertension
# 19997        Married    9852974113  user19998@mail.com  ...               NaN
# 19998         Single    9925330649  user19999@mail.com  ...               NaN
# 19999         Single    9951983597  user20000@mail.com  ...            Asthma
#
#       Primary_Doctor_ID   Insurance_Provider Insurance_Policy_No  \
# 0                  D110     Reliance General           POL127128
# 1                  D102          Star Health           POL919951
# 2                  D109  New India Assurance           POL924889
# 3                  D101     Reliance General           POL912134
# 4                  D110     Reliance General           POL911663
# ...                 ...                  ...                 ...
# 19995              D108        ICICI Lombard           POL308290
# 19996              D102  New India Assurance           POL513474
# 19997              D105          Star Health           POL129135
# 19998              D108        ICICI Lombard           POL531241
# 19999              D101  New India Assurance           POL666690
#
#        Registration_Date  Registration_Date_new  Under_weighted  Age_Group  \
# 0             2023-10-19                   2023           False      Adult
# 1             2023-02-12                   2023           False      Adult
# 2             2020-07-25                   2020           False     Senior
# 3             2020-05-17                   2020           False      Adult
# 4             2021-12-04                   2021           False      Adult
# ...                  ...                    ...             ...        ...
# 19995         2021-07-03                   2021           False      Adult
# 19996         2024-01-18                   2024           False     Senior
# 19997         2020-03-02                   2020           False      Adult
# 19998         2023-04-02                   2023           False      Adult
# 19999         2020-02-18                   2020           False     Senior
#
#       Risk_level Registration_Month
# 0         Normal                 10
# 1         Medium                  2
# 2         Normal                  7
# 3         Normal                  5
# 4           High                 12
# ...          ...                ...
# 19995     Normal                  7
# 19996     Normal                  1
# 19997     Normal                  3
# 19998     Medium                  4
# 19999       High                  2
#
# [20000 rows x 30 columns]

# %% [markdown]
# 59.	Extract Registration Year
#
# 📝 Note: Create a new column storing year only

# %%
df['Registartion_Year']=pd.to_datetime(df['Registration_Date']).dt.year
df
# Out:
#       Patient_ID First_Name Last_Name  Gender  Age Date_of_Birth Blood_Group  \
# 0         P00001     Suresh      Iyer    Male   38    1987-11-23          B+
# 1         P00002       Amit    Sharma  Female   38    1987-04-28          B+
# 2         P00003       Neha     Joshi    Male   56    1969-12-29         AB-
# 3         P00004     Anjali     Patil    Male   47    1978-12-04          A-
# 4         P00005      Rohan     Verma    Male   41    1984-02-11          A-
# ...          ...        ...       ...     ...  ...           ...         ...
# 19995     P19996     Anjali     Mehta    Male   36    1989-10-07          A-
# 19996     P19997      Vikas     Verma  Female   57    1968-10-05         AB-
# 19997     P19998     Anjali     Singh  Female   46    1979-01-16          A-
# 19998     P19999       Amit    Sharma  Female   43    1982-07-30          A-
# 19999     P20000      Pooja     Gupta  Female   58    1967-02-17          O-
#
#       Marital_Status  Phone_Number               Email  ... Primary_Doctor_ID  \
# 0             Single    9698790602      user1@mail.com  ...              D110
# 1            Married    9762620912      user2@mail.com  ...              D102
# 2             Single    9522528550      user3@mail.com  ...              D109
# 3            Married    9196136323      user4@mail.com  ...              D101
# 4             Single    9644918514      user5@mail.com  ...              D110
# ...              ...           ...                 ...  ...               ...
# 19995         Single    9990287038  user19996@mail.com  ...              D108
# 19996         Single    9498150434  user19997@mail.com  ...              D102
# 19997        Married    9852974113  user19998@mail.com  ...              D105
# 19998         Single    9925330649  user19999@mail.com  ...              D108
# 19999         Single    9951983597  user20000@mail.com  ...              D101
#
#         Insurance_Provider Insurance_Policy_No Registration_Date  \
# 0         Reliance General           POL127128        2023-10-19
# 1              Star Health           POL919951        2023-02-12
# 2      New India Assurance           POL924889        2020-07-25
# 3         Reliance General           POL912134        2020-05-17
# 4         Reliance General           POL911663        2021-12-04
# ...                    ...                 ...               ...
# 19995        ICICI Lombard           POL308290        2021-07-03
# 19996  New India Assurance           POL513474        2024-01-18
# 19997          Star Health           POL129135        2020-03-02
# 19998        ICICI Lombard           POL531241        2023-04-02
# 19999  New India Assurance           POL666690        2020-02-18
#
#        Registration_Date_new  Under_weighted  Age_Group  Risk_level  \
# 0                       2023           False      Adult      Normal
# 1                       2023           False      Adult      Medium
# 2                       2020           False     Senior      Normal
# 3                       2020           False      Adult      Normal
# 4                       2021           False      Adult        High
# ...                      ...             ...        ...         ...
# 19995                   2021           False      Adult      Normal
# 19996                   2024           False     Senior      Normal
# 19997                   2020           False      Adult      Normal
# 19998                   2023           False      Adult      Medium
# 19999                   2020           False     Senior        High
#
#       Registration_Month Registartion_Year
# 0                     10              2023
# 1                      2              2023
# 2                      7              2020
# 3                      5              2020
# 4                     12              2021
# ...                  ...               ...
# 19995                  7              2021
# 19996                  1              2024
# 19997                  3              2020
# 19998                  4              2023
# 19999                  2              2020
#
# [20000 rows x 31 columns]

# %% [markdown]
# 60.	Extract Registration Month
#
# 📝 Note: Month should be numeric (1–12).

# %%
df['Registration_Month']=pd.to_datetime(df['Registration_Date']).dt.month
df
# Out:
#       Patient_ID First_Name Last_Name  Gender  Age Date_of_Birth Blood_Group  \
# 0         P00001     Suresh      Iyer    Male   38    1987-11-23          B+
# 1         P00002       Amit    Sharma  Female   38    1987-04-28          B+
# 2         P00003       Neha     Joshi    Male   56    1969-12-29         AB-
# 3         P00004     Anjali     Patil    Male   47    1978-12-04          A-
# 4         P00005      Rohan     Verma    Male   41    1984-02-11          A-
# ...          ...        ...       ...     ...  ...           ...         ...
# 19995     P19996     Anjali     Mehta    Male   36    1989-10-07          A-
# 19996     P19997      Vikas     Verma  Female   57    1968-10-05         AB-
# 19997     P19998     Anjali     Singh  Female   46    1979-01-16          A-
# 19998     P19999       Amit    Sharma  Female   43    1982-07-30          A-
# 19999     P20000      Pooja     Gupta  Female   58    1967-02-17          O-
#
#       Marital_Status  Phone_Number               Email  ... Primary_Doctor_ID  \
# 0             Single    9698790602      user1@mail.com  ...              D110
# 1            Married    9762620912      user2@mail.com  ...              D102
# 2             Single    9522528550      user3@mail.com  ...              D109
# 3            Married    9196136323      user4@mail.com  ...              D101
# 4             Single    9644918514      user5@mail.com  ...              D110
# ...              ...           ...                 ...  ...               ...
# 19995         Single    9990287038  user19996@mail.com  ...              D108
# 19996         Single    9498150434  user19997@mail.com  ...              D102
# 19997        Married    9852974113  user19998@mail.com  ...              D105
# 19998         Single    9925330649  user19999@mail.com  ...              D108
# 19999         Single    9951983597  user20000@mail.com  ...              D101
#
#         Insurance_Provider Insurance_Policy_No Registration_Date  \
# 0         Reliance General           POL127128        2023-10-19
# 1              Star Health           POL919951        2023-02-12
# 2      New India Assurance           POL924889        2020-07-25
# 3         Reliance General           POL912134        2020-05-17
# 4         Reliance General           POL911663        2021-12-04
# ...                    ...                 ...               ...
# 19995        ICICI Lombard           POL308290        2021-07-03
# 19996  New India Assurance           POL513474        2024-01-18
# 19997          Star Health           POL129135        2020-03-02
# 19998        ICICI Lombard           POL531241        2023-04-02
# 19999  New India Assurance           POL666690        2020-02-18
#
#        Registration_Date_new  Under_weighted  Age_Group  Risk_level  \
# 0                       2023           False      Adult      Normal
# 1                       2023           False      Adult      Medium
# 2                       2020           False     Senior      Normal
# 3                       2020           False      Adult      Normal
# 4                       2021           False      Adult        High
# ...                      ...             ...        ...         ...
# 19995                   2021           False      Adult      Normal
# 19996                   2024           False     Senior      Normal
# 19997                   2020           False      Adult      Normal
# 19998                   2023           False      Adult      Medium
# 19999                   2020           False     Senior        High
#
#       Registration_Month Registartion_Year
# 0                     10              2023
# 1                      2              2023
# 2                      7              2020
# 3                      5              2020
# 4                     12              2021
# ...                  ...               ...
# 19995                  7              2021
# 19996                  1              2024
# 19997                  3              2020
# 19998                  4              2023
# 19999                  2              2020
#
# [20000 rows x 31 columns]

# %% [markdown]
# 61.	Create column Is_Senior (Age > 60)
#
# 📝 Note: True if Age > 60, else False.

# %%
df['Is_Senior']=df['Age'].apply(lambda i: 'Senior'if i>60  else'Not Senior')
df['Is_Senior']
# Out:
# 0        Not Senior
# 1        Not Senior
# 2        Not Senior
# 3        Not Senior
# 4        Not Senior
#             ...
# 19995    Not Senior
# 19996    Not Senior
# 19997    Not Senior
# 19998    Not Senior
# 19999    Not Senior
# Name: Is_Senior, Length: 20000, dtype: object

# %% [markdown]
# 62.	Create column High_Risk_Patient
#
# 📝 Note:
#
# o	BMI > 30
#
# o	AND Chronic_Condition ≠ "None"

# %%
df['High_Risk_Patient']=(df['BMI']>30) & (df['Chronic_Condition']!="None")
df['High_Risk_Patient']
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4         True
#          ...
# 19995    False
# 19996    False
# 19997    False
# 19998    False
# 19999     True
# Name: High_Risk_Patient, Length: 20000, dtype: bool

# %% [markdown]
# 63.	Convert Gender column to category type
#
# 📝 Note: Improves memory efficiency.

# %%
df['Gender'] = df['Gender'].astype('category')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 33 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Patient_ID             20000 non-null  object
#  1   First_Name             20000 non-null  object
#  2   Last_Name              20000 non-null  object
#  3   Gender                 20000 non-null  category
#  4   Age                    20000 non-null  int64
#  5   Date_of_Birth          20000 non-null  object
#  6   Blood_Group            20000 non-null  object
#  7   Marital_Status         20000 non-null  object
#  8   Phone_Number           20000 non-null  int64
#  9   Email                  20000 non-null  object
#  10  Address                20000 non-null  object
#  11  City                   20000 non-null  object
#  12  State                  20000 non-null  object
#  13  Country                20000 non-null  object
#  14  Pincode                20000 non-null  int64
#  15  Height_cm              20000 non-null  int64
#  16  Weight_kg              20000 non-null  int64
#  17  BMI                    20000 non-null  float64
#  18  Smoking_Status         20000 non-null  object
#  19  Alcohol_Consumption    20000 non-null  object
#  20  Chronic_Condition      15991 non-null  object
#  21  Primary_Doctor_ID      20000 non-null  object
#  22  Insurance_Provider     20000 non-null  object
#  23  Insurance_Policy_No    20000 non-null  object
#  24  Registration_Date      20000 non-null  object
#  25  Registration_Date_new  20000 non-null  int32
#  26  Under_weighted         20000 non-null  bool
#  27  Age_Group              20000 non-null  object
#  28  Risk_level             20000 non-null  object
#  29  Registration_Month     20000 non-null  int32
#  30  Registartion_Year      20000 non-null  int32
#  31  Is_Senior              20000 non-null  object
#  32  High_Risk_Patient      20000 non-null  bool
# dtypes: bool(2), category(1), float64(1), int32(3), int64(5), object(21)
# memory usage: 4.4+ MB

# %% [markdown]
# 64.	Convert Blood_Group column to category
#
# 📝 Note: Limited unique values → ideal for category

# %%
df['Blood_Group']=df['Blood_Group'].astype('category')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 33 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Patient_ID             20000 non-null  object
#  1   First_Name             20000 non-null  object
#  2   Last_Name              20000 non-null  object
#  3   Gender                 20000 non-null  category
#  4   Age                    20000 non-null  int64
#  5   Date_of_Birth          20000 non-null  object
#  6   Blood_Group            20000 non-null  category
#  7   Marital_Status         20000 non-null  object
#  8   Phone_Number           20000 non-null  int64
#  9   Email                  20000 non-null  object
#  10  Address                20000 non-null  object
#  11  City                   20000 non-null  object
#  12  State                  20000 non-null  object
#  13  Country                20000 non-null  object
#  14  Pincode                20000 non-null  int64
#  15  Height_cm              20000 non-null  int64
#  16  Weight_kg              20000 non-null  int64
#  17  BMI                    20000 non-null  float64
#  18  Smoking_Status         20000 non-null  object
#  19  Alcohol_Consumption    20000 non-null  object
#  20  Chronic_Condition      15991 non-null  object
#  21  Primary_Doctor_ID      20000 non-null  object
#  22  Insurance_Provider     20000 non-null  object
#  23  Insurance_Policy_No    20000 non-null  object
#  24  Registration_Date      20000 non-null  object
#  25  Registration_Date_new  20000 non-null  int32
#  26  Under_weighted         20000 non-null  bool
#  27  Age_Group              20000 non-null  object
#  28  Risk_level             20000 non-null  object
#  29  Registration_Month     20000 non-null  int32
#  30  Registartion_Year      20000 non-null  int32
#  31  Is_Senior              20000 non-null  object
#  32  High_Risk_Patient      20000 non-null  bool
# dtypes: bool(2), category(2), float64(1), int32(3), int64(5), object(20)
# memory usage: 4.3+ MB

# %% [markdown]
# 65.	Rename column Phone_Number to Contact_Number
#
# 📝 Note: Use rename operation.

# %%
df=df.rename(columns={'Phone_Number':'Contact_Number'})
df
# Out:
#       Patient_ID First_Name Last_Name  Gender  Age Date_of_Birth Blood_Group  \
# 0         P00001     Suresh      Iyer    Male   38    1987-11-23          B+
# 1         P00002       Amit    Sharma  Female   38    1987-04-28          B+
# 2         P00003       Neha     Joshi    Male   56    1969-12-29         AB-
# 3         P00004     Anjali     Patil    Male   47    1978-12-04          A-
# 4         P00005      Rohan     Verma    Male   41    1984-02-11          A-
# ...          ...        ...       ...     ...  ...           ...         ...
# 19995     P19996     Anjali     Mehta    Male   36    1989-10-07          A-
# 19996     P19997      Vikas     Verma  Female   57    1968-10-05         AB-
# 19997     P19998     Anjali     Singh  Female   46    1979-01-16          A-
# 19998     P19999       Amit    Sharma  Female   43    1982-07-30          A-
# 19999     P20000      Pooja     Gupta  Female   58    1967-02-17          O-
#
#       Marital_Status  Contact_Number               Email  ...  \
# 0             Single      9698790602      user1@mail.com  ...
# 1            Married      9762620912      user2@mail.com  ...
# 2             Single      9522528550      user3@mail.com  ...
# 3            Married      9196136323      user4@mail.com  ...
# 4             Single      9644918514      user5@mail.com  ...
# ...              ...             ...                 ...  ...
# 19995         Single      9990287038  user19996@mail.com  ...
# 19996         Single      9498150434  user19997@mail.com  ...
# 19997        Married      9852974113  user19998@mail.com  ...
# 19998         Single      9925330649  user19999@mail.com  ...
# 19999         Single      9951983597  user20000@mail.com  ...
#
#       Insurance_Policy_No Registration_Date Registration_Date_new  \
# 0               POL127128        2023-10-19                  2023
# 1               POL919951        2023-02-12                  2023
# 2               POL924889        2020-07-25                  2020
# 3               POL912134        2020-05-17                  2020
# 4               POL911663        2021-12-04                  2021
# ...                   ...               ...                   ...
# 19995           POL308290        2021-07-03                  2021
# 19996           POL513474        2024-01-18                  2024
# 19997           POL129135        2020-03-02                  2020
# 19998           POL531241        2023-04-02                  2023
# 19999           POL666690        2020-02-18                  2020
#
#       Under_weighted  Age_Group  Risk_level  Registration_Month  \
# 0              False      Adult      Normal                  10
# 1              False      Adult      Medium                   2
# 2              False     Senior      Normal                   7
# 3              False      Adult      Normal                   5
# 4              False      Adult        High                  12
# ...              ...        ...         ...                 ...
# 19995          False      Adult      Normal                   7
# 19996          False     Senior      Normal                   1
# 19997          False      Adult      Normal                   3
# 19998          False      Adult      Medium                   4
# 19999          False     Senior        High                   2
#
#        Registartion_Year   Is_Senior High_Risk_Patient
# 0                   2023  Not Senior             False
# 1                   2023  Not Senior             False
# 2                   2020  Not Senior             False
# 3                   2020  Not Senior             False
# 4                   2021  Not Senior              True
# ...                  ...         ...               ...
# 19995               2021  Not Senior             False
# 19996               2024  Not Senior             False
# 19997               2020  Not Senior             False
# 19998               2023  Not Senior             False
# 19999               2020  Not Senior              True
#
# [20000 rows x 33 columns]

# %% [markdown]
# 66.	Drop Email column
#
# 📝 Note: Remove unnecessary or sensitive data

# %%
df = df.drop(columns=['Email'])

# %%
df
# Out:
#       Patient_ID First_Name Last_Name  Gender  Age Date_of_Birth Blood_Group  \
# 0         P00001     Suresh      Iyer    Male   38    1987-11-23          B+
# 1         P00002       Amit    Sharma  Female   38    1987-04-28          B+
# 2         P00003       Neha     Joshi    Male   56    1969-12-29         AB-
# 3         P00004     Anjali     Patil    Male   47    1978-12-04          A-
# 4         P00005      Rohan     Verma    Male   41    1984-02-11          A-
# ...          ...        ...       ...     ...  ...           ...         ...
# 19995     P19996     Anjali     Mehta    Male   36    1989-10-07          A-
# 19996     P19997      Vikas     Verma  Female   57    1968-10-05         AB-
# 19997     P19998     Anjali     Singh  Female   46    1979-01-16          A-
# 19998     P19999       Amit    Sharma  Female   43    1982-07-30          A-
# 19999     P20000      Pooja     Gupta  Female   58    1967-02-17          O-
#
#       Marital_Status  Contact_Number        Address  ... Insurance_Policy_No  \
# 0             Single      9698790602  Local Address  ...           POL127128
# 1            Married      9762620912  Local Address  ...           POL919951
# 2             Single      9522528550  Local Address  ...           POL924889
# 3            Married      9196136323  Local Address  ...           POL912134
# 4             Single      9644918514  Local Address  ...           POL911663
# ...              ...             ...            ...  ...                 ...
# 19995         Single      9990287038  Local Address  ...           POL308290
# 19996         Single      9498150434  Local Address  ...           POL513474
# 19997        Married      9852974113  Local Address  ...           POL129135
# 19998         Single      9925330649  Local Address  ...           POL531241
# 19999         Single      9951983597  Local Address  ...           POL666690
#
#       Registration_Date Registration_Date_new  Under_weighted  Age_Group  \
# 0            2023-10-19                  2023           False      Adult
# 1            2023-02-12                  2023           False      Adult
# 2            2020-07-25                  2020           False     Senior
# 3            2020-05-17                  2020           False      Adult
# 4            2021-12-04                  2021           False      Adult
# ...                 ...                   ...             ...        ...
# 19995        2021-07-03                  2021           False      Adult
# 19996        2024-01-18                  2024           False     Senior
# 19997        2020-03-02                  2020           False      Adult
# 19998        2023-04-02                  2023           False      Adult
# 19999        2020-02-18                  2020           False     Senior
#
#        Risk_level  Registration_Month Registartion_Year   Is_Senior  \
# 0          Normal                  10              2023  Not Senior
# 1          Medium                   2              2023  Not Senior
# 2          Normal                   7              2020  Not Senior
# 3          Normal                   5              2020  Not Senior
# 4            High                  12              2021  Not Senior
# ...           ...                 ...               ...         ...
# 19995      Normal                   7              2021  Not Senior
# 19996      Normal                   1              2024  Not Senior
# 19997      Normal                   3              2020  Not Senior
# 19998      Medium                   4              2023  Not Senior
# 19999        High                   2              2020  Not Senior
#
#       High_Risk_Patient
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                  True
# ...                 ...
# 19995             False
# 19996             False
# 19997             False
# 19998             False
# 19999              True
#
# [20000 rows x 32 columns]

# %% [markdown]
# 67.	Fill missing Chronic_Condition with “Unknown”
#
# 📝 Note: Handle missing values.

# %%
df['Chronic_Condition'].fillna('Unknown',inplace=True)
df['Chronic_Condition']
# Out:
# /tmp/ipykernel_45094/3979773431.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Chronic_Condition'].fillna('Unknown',inplace=True)
# 0             Thyroid
# 1             Unknown
# 2             Thyroid
# 3            Diabetes
# 4        Hypertension
#              ...
# 19995    Hypertension
# 19996    Hypertension
# 19997         Unknown
# 19998         Unknown
# 19999          Asthma
# Name: Chronic_Condition, Length: 20000, dtype: object

# %% [markdown]
# 68.	Create BMI_Category
#
# 📝 Note:
#
# o	<18.5 → Underweight
#
# o	18.5–25 → Normal
#
# o	25–30 → Overweight
#
# o	30 → Obese

# %%
df['BMI_Category']=df['BMI'].apply(lambda i: 'Underweight'if i<18.5 else('Normal'if 18.5<=i<25 else('Overweight' if 25<=i<30 else'Obese')))
df
# Out:
#       Patient_ID First_Name Last_Name  Gender  Age Date_of_Birth Blood_Group  \
# 0         P00001     Suresh      Iyer    Male   38    1987-11-23          B+
# 1         P00002       Amit    Sharma  Female   38    1987-04-28          B+
# 2         P00003       Neha     Joshi    Male   56    1969-12-29         AB-
# 3         P00004     Anjali     Patil    Male   47    1978-12-04          A-
# 4         P00005      Rohan     Verma    Male   41    1984-02-11          A-
# ...          ...        ...       ...     ...  ...           ...         ...
# 19995     P19996     Anjali     Mehta    Male   36    1989-10-07          A-
# 19996     P19997      Vikas     Verma  Female   57    1968-10-05         AB-
# 19997     P19998     Anjali     Singh  Female   46    1979-01-16          A-
# 19998     P19999       Amit    Sharma  Female   43    1982-07-30          A-
# 19999     P20000      Pooja     Gupta  Female   58    1967-02-17          O-
#
#       Marital_Status  Contact_Number        Address  ... Registration_Date  \
# 0             Single      9698790602  Local Address  ...        2023-10-19
# 1            Married      9762620912  Local Address  ...        2023-02-12
# 2             Single      9522528550  Local Address  ...        2020-07-25
# 3            Married      9196136323  Local Address  ...        2020-05-17
# 4             Single      9644918514  Local Address  ...        2021-12-04
# ...              ...             ...            ...  ...               ...
# 19995         Single      9990287038  Local Address  ...        2021-07-03
# 19996         Single      9498150434  Local Address  ...        2024-01-18
# 19997        Married      9852974113  Local Address  ...        2020-03-02
# 19998         Single      9925330649  Local Address  ...        2023-04-02
# 19999         Single      9951983597  Local Address  ...        2020-02-18
#
#       Registration_Date_new Under_weighted  Age_Group  Risk_level  \
# 0                      2023          False      Adult      Normal
# 1                      2023          False      Adult      Medium
# 2                      2020          False     Senior      Normal
# 3                      2020          False      Adult      Normal
# 4                      2021          False      Adult        High
# ...                     ...            ...        ...         ...
# 19995                  2021          False      Adult      Normal
# 19996                  2024          False     Senior      Normal
# 19997                  2020          False      Adult      Normal
# 19998                  2023          False      Adult      Medium
# 19999                  2020          False     Senior        High
#
#        Registration_Month  Registartion_Year   Is_Senior High_Risk_Patient  \
# 0                      10               2023  Not Senior             False
# 1                       2               2023  Not Senior             False
# 2                       7               2020  Not Senior             False
# 3                       5               2020  Not Senior             False
# 4                      12               2021  Not Senior              True
# ...                   ...                ...         ...               ...
# 19995                   7               2021  Not Senior             False
# 19996                   1               2024  Not Senior             False
# 19997                   3               2020  Not Senior             False
# 19998                   4               2023  Not Senior             False
# 19999                   2               2020  Not Senior              True
#
#       BMI_Category
# 0           Normal
# 1       Overweight
# 2           Normal
# 3           Normal
# 4            Obese
# ...            ...
# 19995       Normal
# 19996       Normal
# 19997       Normal
# 19998   Overweight
# 19999        Obese
#
# [20000 rows x 33 columns]

# %% [markdown]
# 69.	Normalize Height column
#
# 📝 Note: Scale values between 0 and 1.

# %%
df['Height_Normalized'] = (df['Height_cm'] - df['Height_cm'].min()) / (df['Height_cm'].max() - df['Height_cm'].min())
df['Height_Normalized']
# Out:
# 0        0.166667
# 1        0.600000
# 2        0.633333
# 3        0.400000
# 4        0.033333
#            ...
# 19995    0.766667
# 19996    0.800000
# 19997    0.566667
# 19998    0.233333
# 19999    0.166667
# Name: Height_Normalized, Length: 20000, dtype: float64

# %% [markdown]
# 70.	Standardize Weight column
#
# 📝 Note: Mean = 0, Standard Deviation = 1.

# %%
df['Weight_Standardized'] = (df['Weight_kg'] - df['Weight_kg'].mean()) / df['Weight_kg'].std()
df['Weight_Standardized']
# Out:
# 0       -1.688900
# 1        0.340240
# 2        0.086598
# 3       -0.843425
# 4        1.439358
#            ...
# 19995   -0.589782
# 19996   -0.758877
# 19997   -1.266162
# 19998    0.086598
# 19999    1.608453
# Name: Weight_Standardized, Length: 20000, dtype: float64

# %% [markdown]
# 71.	Add column Insurance_Status (Yes/No)
#
# 📝 Note: Yes if Insurance_Provider exists, else No

# %%
df['Insurance_Status']=np.where(df['Insurance_Provider'],'Yes','No')

# %%
df['Insurance_Status']
# Out:
# 0        Yes
# 1        Yes
# 2        Yes
# 3        Yes
# 4        Yes
#         ...
# 19995    Yes
# 19996    Yes
# 19997    Yes
# 19998    Yes
# 19999    Yes
# Name: Insurance_Status, Length: 20000, dtype: object

# %% [markdown]
# 72.	Create column Patient_Location
#
# 📝 Note: Combine City and State with separator.

# %%
df['Patient_Location'] = df['City'] + ", " + df['State']

# %%
df['Patient_Location']
# Out:
# 0        Navi Mumbai, Maharashtra
# 1             Mumbai, Maharashtra
# 2             Nashik, Maharashtra
# 3             Mumbai, Maharashtra
# 4        Navi Mumbai, Maharashtra
#                    ...
# 19995    Navi Mumbai, Maharashtra
# 19996    Navi Mumbai, Maharashtra
# 19997         Nagpur, Maharashtra
# 19998         Nagpur, Maharashtra
# 19999         Nagpur, Maharashtra
# Name: Patient_Location, Length: 20000, dtype: object

# %% [markdown]
# 73.	Sort patients by BMI descending
#
# 📝 Note: Highest BMI first.

# %%
df['BMI'].sort_values(ascending=False)
# Out:
# 17826    40.0
# 10001    40.0
# 10369    40.0
# 7256     40.0
# 1953     40.0
#          ...
# 10472    15.4
# 9592     15.4
# 19194    15.4
# 15514    15.4
# 19909    15.4
# Name: BMI, Length: 20000, dtype: float64

# %% [markdown]
# 74.	Reset index after sorting
#
# 📝 Note: Clean index after rearranging rows

# %%
df.reset_index(drop=True,inplace=True)
df
# Out:
#       Patient_ID First_Name Last_Name  Gender  Age Date_of_Birth Blood_Group  \
# 0         P00001     Suresh      Iyer    Male   38    1987-11-23          B+
# 1         P00002       Amit    Sharma  Female   38    1987-04-28          B+
# 2         P00003       Neha     Joshi    Male   56    1969-12-29         AB-
# 3         P00004     Anjali     Patil    Male   47    1978-12-04          A-
# 4         P00005      Rohan     Verma    Male   41    1984-02-11          A-
# ...          ...        ...       ...     ...  ...           ...         ...
# 19995     P19996     Anjali     Mehta    Male   36    1989-10-07          A-
# 19996     P19997      Vikas     Verma  Female   57    1968-10-05         AB-
# 19997     P19998     Anjali     Singh  Female   46    1979-01-16          A-
# 19998     P19999       Amit    Sharma  Female   43    1982-07-30          A-
# 19999     P20000      Pooja     Gupta  Female   58    1967-02-17          O-
#
#       Marital_Status  Phone_Number               Email  ... Weight_kg   BMI  \
# 0             Single    9698790602      user1@mail.com  ...        50  20.8
# 1            Married    9762620912      user2@mail.com  ...        74  26.2
# 2             Single    9522528550      user3@mail.com  ...        71  24.9
# 3            Married    9196136323      user4@mail.com  ...        60  22.9
# 4             Single    9644918514      user5@mail.com  ...        87  38.2
# ...              ...           ...                 ...  ...       ...   ...
# 19995         Single    9990287038  user19996@mail.com  ...        63  21.0
# 19996         Single    9498150434  user19997@mail.com  ...        61  20.1
# 19997        Married    9852974113  user19998@mail.com  ...        55  19.7
# 19998         Single    9925330649  user19999@mail.com  ...        71  28.8
# 19999         Single    9951983597  user20000@mail.com  ...        89  37.0
#
#       Smoking_Status Alcohol_Consumption  Chronic_Condition  \
# 0                Yes        Occasionally            Thyroid
# 1                Yes        Occasionally                NaN
# 2                 No                  No            Thyroid
# 3                 No                  No           Diabetes
# 4                 No                  No       Hypertension
# ...              ...                 ...                ...
# 19995             No        Occasionally       Hypertension
# 19996            Yes        Occasionally       Hypertension
# 19997             No        Occasionally                NaN
# 19998            Yes        Occasionally                NaN
# 19999            Yes        Occasionally             Asthma
#
#        Primary_Doctor_ID   Insurance_Provider  Insurance_Policy_No  \
# 0                   D110     Reliance General            POL127128
# 1                   D102          Star Health            POL919951
# 2                   D109  New India Assurance            POL924889
# 3                   D101     Reliance General            POL912134
# 4                   D110     Reliance General            POL911663
# ...                  ...                  ...                  ...
# 19995               D108        ICICI Lombard            POL308290
# 19996               D102  New India Assurance            POL513474
# 19997               D105          Star Health            POL129135
# 19998               D108        ICICI Lombard            POL531241
# 19999               D101  New India Assurance            POL666690
#
#       Registration_Date Under_weighted
# 0            2023-10-19          False
# 1            2023-02-12          False
# 2            2020-07-25          False
# 3            2020-05-17          False
# 4            2021-12-04          False
# ...                 ...            ...
# 19995        2021-07-03          False
# 19996        2024-01-18          False
# 19997        2020-03-02          False
# 19998        2023-04-02          False
# 19999        2020-02-18          False
#
# [20000 rows x 26 columns]

# %% [markdown]
# 75.	Select top 10 highest BMI patients
#
# 📝 Note: Used for high-risk analysis

# %%
df.sort_values(by='BMI', ascending=False).head(10)
# Out:
#       Patient_ID First_Name Last_Name  Gender  Age Date_of_Birth Blood_Group  \
# 17826     P17827     Kavita    Sharma  Female   40    1985-08-05         AB+
# 10001     P10002     Anjali     Singh  Female   56    1969-05-19          B+
# 10369     P10370      Pooja     Singh    Male   34    1991-10-01          O-
# 7256      P07257      Vikas      Iyer    Male   38    1987-02-22          B+
# 1953      P01954      Pooja     Patil    Male   54    1971-07-26          B+
# 2913      P02914      Rahul     Joshi  Female   55    1970-06-27          O+
# 14250     P14251      Rohan     Patil  Female   40    1985-06-23         AB-
# 14268     P14269      Rahul     Singh    Male   35    1990-07-22          A-
# 5024      P05025     Anjali      Iyer  Female   57    1968-11-13          O-
# 17251     P17252     Anjali     Joshi  Female   48    1977-10-07          O-
#
#       Marital_Status  Contact_Number        Address  ... Risk_level  \
# 17826         Single      9425136045  Local Address  ...       High
# 10001         Single      9248354863  Local Address  ...       High
# 10369         Single      9637966832  Local Address  ...       High
# 7256         Married      9754719239  Local Address  ...       High
# 1953          Single      9195154533  Local Address  ...       High
# 2913         Married      9669114317  Local Address  ...       High
# 14250         Single      9713111126  Local Address  ...       High
# 14268         Single      9872545141  Local Address  ...       High
# 5024          Single      9737178788  Local Address  ...       High
# 17251        Married      9254411475  Local Address  ...       High
#
#       Registration_Month Registartion_Year   Is_Senior  High_Risk_Patient  \
# 17826                  4              2022  Not Senior               True
# 10001                 12              2020  Not Senior               True
# 10369                 10              2020  Not Senior               True
# 7256                   3              2021  Not Senior               True
# 1953                   3              2023  Not Senior               True
# 2913                   5              2021  Not Senior               True
# 14250                 10              2023  Not Senior               True
# 14268                  3              2023  Not Senior               True
# 5024                   5              2021  Not Senior               True
# 17251                  5              2020  Not Senior               True
#
#        BMI_Category  Height_Normalized Weight_Standardized Insurance_Status  \
# 17826         Obese                0.0            1.693001              Yes
# 10001         Obese                0.0            1.693001              Yes
# 10369         Obese                0.0            1.693001              Yes
# 7256          Obese                0.0            1.693001              Yes
# 1953          Obese                0.0            1.693001              Yes
# 2913          Obese                0.0            1.693001              Yes
# 14250         Obese                0.0            1.693001              Yes
# 14268         Obese                0.0            1.693001              Yes
# 5024          Obese                0.0            1.693001              Yes
# 17251         Obese                0.0            1.693001              Yes
#
#                Patient_Location
# 17826         Pune, Maharashtra
# 10001       Nagpur, Maharashtra
# 10369         Pune, Maharashtra
# 7256   Navi Mumbai, Maharashtra
# 1953        Nashik, Maharashtra
# 2913   Navi Mumbai, Maharashtra
# 14250  Navi Mumbai, Maharashtra
# 14268       Nagpur, Maharashtra
# 5024        Nagpur, Maharashtra
# 17251         Pune, Maharashtra
#
# [10 rows x 37 columns]

# %% [markdown]
# **SECTION 5: ADVANCED / ANALYTICAL QUESTIONS (76–90)**

# %% [markdown]
# 76.	Find top 5 cities with highest average BMI
#
# 📝 Note: Group → Mean → Sort → Top 5.

# %%
df.groupby('City')['BMI'].mean().sort_values(ascending=False).head()
# Out:
# City
# Mumbai         25.984345
# Pune           25.945328
# Nashik         25.922247
# Navi Mumbai    25.911626
# Nagpur         25.873850
# Name: BMI, dtype: float64

# %% [markdown]
# 77.	Find bottom 5 cities with lowest average BMI
#
# 📝 Note: Ascending order.

# %%
df.groupby('City')['BMI'].mean().sort_values().head()
# Out:
# City
# Nagpur         25.873850
# Navi Mumbai    25.911626
# Nashik         25.922247
# Pune           25.945328
# Mumbai         25.984345
# Name: BMI, dtype: float64

# %% [markdown]
# 78.	Find patients at high cardiovascular risk
#
# 📝 Note:
#
# o	Age > 50
#
# o	BMI > 30
#
# o	Chronic condition present

# %%
df['high_cardiovascular_risk']=(df['Chronic_Condition']=='present') & (df['Age']>50) & (df['BMI']>30)

# %%
df['high_cardiovascular_risk']
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 19995    False
# 19996    False
# 19997    False
# 19998    False
# 19999    False
# Name: high_cardiovascular_risk, Length: 20000, dtype: bool

# %% [markdown]
# 79.	Find doctor handling maximum chronic patients
#
# 📝 Note: Filter chronic patients, then group by doctor.

# %%
a = df[df['Chronic_Condition'] != 'Unknown']
top_doctor = a.groupby('Primary_Doctor_ID')['Patient_ID'].count().sort_values(ascending=False)
print(top_doctor.head(1))
# Out:
# Primary_Doctor_ID
# D107    1493
# Name: Patient_ID, dtype: int64

# %% [markdown]
# 80.	Find insurance provider covering most senior citizens
#
# 📝 Note: Senior = Age > 60.

# %%
seniors_df = df[df['Age'] > 60]
top_provider = seniors_df['Insurance_Provider'].max()
print(top_provider)
# Out:
# nan

# %% [markdown]
# 81.	Find patients eligible for lifestyle counseling
#
# 📝 Note: BMI > 25 OR Smoking = Yes OR Alcohol = Occasionally

# %%
df['lifestyle_counseling']=(df['BMI']>25) | (df['Smoking_Status']=='Yes') | (df['Alcohol_Consumption']=='Occasionally')
df['lifestyle_counseling']
# Out:
# 0         True
# 1         True
# 2        False
# 3        False
# 4         True
#          ...
# 19995     True
# 19996     True
# 19997     True
# 19998     True
# 19999     True
# Name: lifestyle_counseling, Length: 20000, dtype: bool

# %% [markdown]
# 82.	Identify potential ICU-risk patients
#
# 📝 Note: Age > 65 AND BMI > 30 AND chronic condition present.

# %%
df['ICU-risk']=(df['Age']>30) & (df['Chronic_Condition']=='Yes')

# %%
df['ICU-risk']
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 19995    False
# 19996    False
# 19997    False
# 19998    False
# 19999    False
# Name: ICU-risk, Length: 20000, dtype: bool

# %% [markdown]
# 83.	Find correlation between Age and BMI
#
# 📝 Note: Measures relationship strength.

# %%
correlation = df['Age'].corr(df['BMI'])
print(f"Correlation between Age and BMI: {correlation:.2f}")
# Out:
# Correlation between Age and BMI: -0.01

# %% [markdown]
# 84.	Detect BMI outliers using IQR
#
# 📝 Note:
#
# o	Lower bound = Q1 − 1.5×IQR
#
# o	Upper bound = Q3 + 1.5×IQR

# %%
Q1=df['BMI'].quantile(0.25)
Q3=df['BMI'].quantile(0.75)
IQR=Q3-Q1
Lower_bound=Q1-1.5*IQR
Upper_bound=Q3+1.5*IQR
Outliner=df[(df['BMI']<Lower_bound) | (df['BMI']>Upper_bound)]
print(f"Lower Bound: {Lower_bound}, Upper Bound: {Upper_bound}")
print(Outliner)
# Out:
# Lower Bound: 10.250000000000002, Upper Bound: 41.05
# Empty DataFrame
# Columns: [Patient_ID, First_Name, Last_Name, Gender, Age, Date_of_Birth, Blood_Group, Marital_Status, Contact_Number, Address, City, State, Country, Pincode, Height_cm, Weight_kg, BMI, Smoking_Status, Alcohol_Consumption, Chronic_Condition, Primary_Doctor_ID, Insurance_Provider, Insurance_Policy_No, Registration_Date, Registration_Date_new, Under_weighted, Age_Group, Risk_level, Registration_Month, Registartion_Year, Is_Senior, High_Risk_Patient, BMI_Category, Height_Normalized, Weight_Standardized, Insurance_Status, Patient_Location, high_cardiovascular_risk, lifestyle_counseling, ICU-risk]
# Index: []
#
# [0 rows x 40 columns]

# %% [markdown]
# 85.	Create pivot table of Gender vs Chronic Condition
#
# 📝 Note: Rows = Gender, Columns = Chronic_Condition.

# %%
pivot_table=df.pivot_table(index='Gender', values='Chronic_Condition',aggfunc='count')
print(pivot_table)
# Out:
#         Chronic_Condition
# Gender
# Female               9858
# Male                10142
# /tmp/ipykernel_45094/2742968215.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot_table=df.pivot_table(index='Gender', values='Chronic_Condition',aggfunc='count')

# %% [markdown]
# 86.	Create pivot of City vs Smoking_Status
#
# 📝 Note: Cross-tab city and smoking habits.

# %%
pivot_table2=df.pivot_table(index='City',values='Smoking_Status',aggfunc='count')
print(pivot_table2)
# Out:
#              Smoking_Status
# City
# Mumbai                 3922
# Nagpur                 4042
# Nashik                 4032
# Navi Mumbai            3905
# Pune                   4099

# %% [markdown]
# 87.	Calculate rolling average BMI by age
#
# 📝 Note: Use window size (e.g., 5).

# %%
age_bmi = df[['Age', 'BMI']]
age_bmi = age_bmi.sort_values('Age')
age_bmi['Rolling_Avg_BMI'] = age_bmi['BMI'].rolling(window=5, min_periods=1).mean()
print(age_bmi.head())
# Out:
#        Age   BMI  Rolling_Avg_BMI
# 12278   27  23.7        23.700000
# 846     27  25.1        24.400000
# 17446   27  32.4        27.066667
# 755     27  22.1        25.825000
# 760     27  30.5        26.760000

# %% [markdown]
# 88.	Rank patients by BMI within each city
#
# 📝 Note: Ranking should reset per city.

# %%
df['BMI_Rank_In_City'] = df.groupby('City')['BMI'].rank(ascending=False, method='min')
df_sorted = df.sort_values(['City', 'BMI_Rank_In_City'])
df['BMI_Rank_In_City']
# Out:
# 0        3186.0
# 1        1793.0
# 2        2193.0
# 3        2659.0
# 4          32.0
#           ...
# 19995    3128.0
# 19996    3328.0
# 19997    3520.0
# 19998    1145.0
# 19999      90.0
# Name: BMI_Rank_In_City, Length: 20000, dtype: float64

# %% [markdown]
# 89.	Find percentile rank of BMI
#
# 📝 Note: Shows relative BMI position.

# %%
df['BMI_Percentile'] = df['BMI'].rank(pct=True) * 100
df_sorted = df.sort_values('BMI_Percentile', ascending=False)
df['BMI_Percentile']
# Out:
# 0        18.4125
# 1        53.8275
# 2        45.2000
# 3        32.1975
# 4        99.0525
#           ...
# 19995    19.5950
# 19996    14.4375
# 19997    12.3325
# 19998    70.8675
# 19999    97.7850
# Name: BMI_Percentile, Length: 20000, dtype: float64

# %% [markdown]
# 90.	Export cleaned DataFrame to CSV
#
# 📝 Note: Final output after transformations.

# %%
df.to_csv('cleaned_patient_data.csv', index=False)
print("File saved successfully!")
# Out:
# File saved successfully!
